# %% [markdown]
# # SQL Data Analysis Workshop

# %% [markdown]
#  This workshop is designed to help you build practical SQL skills by analyzing real-world business data.
#
# The tasks are divided into 4 levels to gradually progress from basic data retrieval to advanced analysis. Each level focuses on specific SQL concepts and challenges, allowing you to practice query writing, data filtering, aggregations, joins, and subqueries.
# - Level 1: Basic SQL queries (SELECT, WHERE, ORDER BY, COUNT).
# - Level 2: Aggregations (SUM, AVG, GROUP BY) and basic joins.
# - Level 3: Complex joins, subqueries, and multi-table analysis.
# - Level 4: Advanced analytical tasks focused on complex queries, subqueries, and aggregations..
#
# This structured approach ensures you build confidence and expertise in SQL, preparing you for real-world data analysis challenges. 🚀

# %% [markdown]
# ---
# ## Setup the work environment

# %% [markdown]
# #### 1. Library's import

# %%
import mysql.connector
import pandas as pd

# %% [markdown]
# #### 2. Connecting to the Database

# %%
connection=mysql.connector.connect(
    host="localhost",
    user="root",
    password="",
    database="bikestore"
)
cursor=connection.cursor()

# %% [markdown]
# #### 3. Setup for SQL Magic

# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %sql mysql+pymysql://root:@localhost/bikestore

# %% [markdown]
# ---
# ## Level 1: Beginner – Basic Queries (using SQL Magic)

# %% [markdown]
# ### Task 1: Retrieve all rows and columns from the customers table.

# %%
# %sql select * from customers
# Out:
# Running query in 'mysql+pymysql://root:***@localhost/bikestore'
# c:\Users\alaaa\anaconda3\Lib\site-packages\sql\connection\connection.py:866: JupySQLRollbackPerformed: Found invalid transaction. JupySQL executed a ROLLBACK operation.
#   warnings.warn(
# 1445 rows affected.
# +-------------+------------+-----------+----------------+----------------------------+-------------------------+-----------------+-------+----------+
# | customer_id | first_name | last_name |     phone      |           email            |          street         |       city      | state | zip_code |
# +-------------+------------+-----------+----------------+----------------------------+-------------------------+-----------------+-------+----------+
# |      1      |   Debra    |   Burks   |      None      |   debra.burks@yahoo.com    |    9273 Thorne Ave.     |   Orchard Park  |   NY  |  14127   |
# |      2      |   Kasha    |    Todd   |      None      |    kasha.todd@yahoo.com    |     910 Vine Street     |     Campbell    |   CA  |  95008   |
# |      3      |   Tameka   |   Fisher  |      None      |   tameka.fisher@aol.com    |  769C Honey Creek St.   |  Redondo Beach  |   CA  |  90278   |
# |      4      |   Daryl    |   Spence  |      None      |    daryl.spence@aol.com    |     988 Pearl Lane      |    Uniondale    |   NY  |  11553   |
# |      5      | Charolette |    Rice   | (916) 381-6003 |  charolette.rice@msn.com   |      107 River Dr.      |    Sacramento   |   CA  |  95820   |
# |      6      |  Lyndsey   |    Bean   |      None      |  lyndsey.bean@hotmail.com  |      769 West Road      |     Fairport    |   NY  |  14450   |
# |      7      |  Latasha   |    Hays   | (716) 986-3359 |  latasha.hays@hotmail.com  | 7014 Manor Station Rd.  |     Buffalo     |   NY  |  14215   |
# |      8      | Jacquline  |   Duncan  |      None      | jacquline.duncan@yahoo.com |      15 Brown St.       | Jackson Heights |   NY  |  11372   |
# |      9      |  Genoveva  |  Baldwin  |      None      |  genoveva.baldwin@msn.com  |    8550 Spruce Drive    | Port Washington |   NY  |  11050   |
# |      10     |  Pamelia   |   Newman  |      None      |  pamelia.newman@gmail.com  |    476 Chestnut Ave.    |      Monroe     |   NY  |  10950   |
# +-------------+------------+-----------+----------------+----------------------------+-------------------------+-----------------+-------+----------+
# Truncated to displaylimit of 10.

# %% [markdown]
# ### Task 2: Retrieve customers who live in the city "New York".

# %%
# %sql select * from customers where city="New York"
# Out:
# Running query in 'mysql+pymysql://root:***@localhost/bikestore'
# 7 rows affected.
# +-------------+------------+-----------+----------------+----------------------------+---------------------------+----------+-------+----------+
# | customer_id | first_name | last_name |     phone      |           email            |           street          |   city   | state | zip_code |
# +-------------+------------+-----------+----------------+----------------------------+---------------------------+----------+-------+----------+
# |      16     |   Emmitt   |  Sanchez  | (212) 945-8823 | emmitt.sanchez@hotmail.com |   461 Squaw Creek Road    | New York |   NY  |  10002   |
# |     178     |  Genoveva  |   Tyler   | (212) 152-6381 |  genoveva.tyler@gmail.com  |    8121 Windfall Ave.     | New York |   NY  |  10002   |
# |     327     |   Sharie   |  Alvarez  | (212) 211-7621 |   sharie.alvarez@msn.com   | 987 West Leatherwood Dr.  | New York |   NY  |  10002   |
# |     411     |  Octavia   |    Case   | (212) 171-1335 |    octavia.case@aol.com    |      40 Charles Road      | New York |   NY  |  10002   |
# |     854     |   Phylis   |   Adkins  | (212) 325-9145 |   phylis.adkins@msn.com    |      7781 James Ave.      | New York |   NY  |  10002   |
# |     927     | Guillermo  |    Hart   | (212) 652-7198 | guillermo.hart@hotmail.com |  81 Indian Summer Drive   | New York |   NY  |  10002   |
# |     1016    |   Shenna   |   Benton  | (212) 578-2912 |   shenna.benton@msn.com    |   57 Shadow Brook Road    | New York |   NY  |  10002   |
# +-------------+------------+-----------+----------------+----------------------------+---------------------------+----------+-------+----------+

# %% [markdown]
# ### Task 3: Retrieve all products sorted by their price in descending order.

# %%
# %sql select * from products order by list_price desc
# Out:
# Running query in 'mysql+pymysql://root:***@localhost/bikestore'
# 321 rows affected.
# +------------+----------------------------------------+----------+-------------+------------+------------+
# | product_id |              product_name              | brand_id | category_id | model_year | list_price |
# +------------+----------------------------------------+----------+-------------+------------+------------+
# |    155     |     Trek Domane SLR 9 Disc - 2018      |    9     |      7      |    2018    |  11999.99  |
# |    149     |     Trek Domane SLR 8 Disc - 2018      |    9     |      7      |    2018    |  7499.99   |
# |     51     |    Trek Silque SLR 8 Women's - 2017    |    9     |      7      |    2017    |  6499.99   |
# |    169     |        Trek Emonda SLR 8 - 2018        |    9     |      7      |    2018    |  6499.99   |
# |    157     | Trek Domane SL Frameset Women's - 2018 |    9     |      7      |    2018    |  6499.99   |
# |    156     |     Trek Domane SL Frameset - 2018     |    9     |      7      |    2018    |  6499.99   |
# |     50     |    Trek Silque SLR 7 Women's - 2017    |    9     |      7      |    2017    |  5999.99   |
# |    177     |     Trek Domane SLR 6 Disc - 2018      |    9     |      7      |    2018    |  5499.99   |
# |    154     | Trek Domane SLR 6 Disc Women's - 2018  |    9     |      7      |    2018    |  5499.99   |
# |    148     |      Trek Domane SL 8 Disc - 2018      |    9     |      7      |    2018    |  5499.99   |
# +------------+----------------------------------------+----------+-------------+------------+------------+
# Truncated to displaylimit of 10.

# %% [markdown]
# ### Task 4: Find Orders by Status

# %% [markdown]
# #### Task 4.1: Retrieve all orders with status "Completed".

# %%
# %%sql select * from orders
# join order_statuses
# on orders.order_status=order_statuses.status_id
# where order_statuses.status_id=4
# Out:
# Running query in 'mysql+pymysql://root:***@localhost/bikestore'
# 1445 rows affected.
# +----------+-------------+--------------+------------+---------------+--------------+----------+----------+-----------+--------------------+
# | order_id | customer_id | order_status | order_date | required_date | shipped_date | store_id | staff_id | status_id | status_description |
# +----------+-------------+--------------+------------+---------------+--------------+----------+----------+-----------+--------------------+
# |    1     |     259     |      4       | 2016-01-01 |   2016-01-03  |  2016-01-03  |    1     |    2     |     4     |     Completed      |
# |    2     |     1212    |      4       | 2016-01-01 |   2016-01-04  |  2016-01-03  |    2     |    6     |     4     |     Completed      |
# |    3     |     523     |      4       | 2016-01-02 |   2016-01-05  |  2016-01-03  |    2     |    7     |     4     |     Completed      |
# |    4     |     175     |      4       | 2016-01-03 |   2016-01-04  |  2016-01-05  |    1     |    3     |     4     |     Completed      |
# |    5     |     1324    |      4       | 2016-01-03 |   2016-01-06  |  2016-01-06  |    2     |    6     |     4     |     Completed      |
# |    6     |      94     |      4       | 2016-01-04 |   2016-01-07  |  2016-01-05  |    2     |    6     |     4     |     Completed      |
# |    7     |     324     |      4       | 2016-01-04 |   2016-01-07  |  2016-01-05  |    2     |    6     |     4     |     Completed      |
# |    8     |     1204    |      4       | 2016-01-04 |   2016-01-05  |  2016-01-05  |    2     |    7     |     4     |     Completed      |
# |    9     |      60     |      4       | 2016-01-05 |   2016-01-08  |  2016-01-08  |    1     |    2     |     4     |     Completed      |
# |    10    |     442     |      4       | 2016-01-05 |   2016-01-06  |  2016-01-06  |    2     |    6     |     4     |     Completed      |
# +----------+-------------+--------------+------------+---------------+--------------+----------+----------+-----------+--------------------+
# Truncated to displaylimit of 10.

# %% [markdown]
# #### Task 4.1: Retrieve count of orders with status "Rejected".

# %%
# %%sql select count(orders.order_id) as RejectedOrders
# from orders
# join order_statuses
# on orders.order_status=order_statuses.status_id
# where order_statuses.status_id=3
# Out:
# Running query in 'mysql+pymysql://root:***@localhost/bikestore'
# 1 rows affected.
# +----------------+
# | RejectedOrders |
# +----------------+
# |       45       |
# +----------------+

# %% [markdown]
# ### Task 5: Count how many customers exist in the customers table.

# %%
# %sql select count(customer_id) as NumOfCustomers from customers
# Out:
# Running query in 'mysql+pymysql://root:***@localhost/bikestore'
# 1 rows affected.
# +----------------+
# | NumOfCustomers |
# +----------------+
# |      1445      |
# +----------------+

# %% [markdown]
# ---
# ## Level 2: Intermediate – Aggregations and Basic Joins
# ##### (Task 1,2,3 using Pandas read_sql and Task 4,5 using execute and fetchall() in mysql.connector)

# %% [markdown]
# ### Task 1: Calculate the total revenue (sum of list_price * quantity) from the order_items table.

# %%
query=""" select sum(list_price*quantity)as TotalRevenue
from order_items
"""
rows=pd.read_sql(query,connection)
rows
# Out:
# C:\Users\alaaa\AppData\Local\Temp\ipykernel_3076\194878474.py:4: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   rows=pd.read_sql(query,connection)
#    TotalRevenue
# 0    8578988.88

# %% [markdown]
# ### Task 2: Calculate the average price of products in the products table.

# %%
query="select avg(list_price) as AvgPrice from products"
rows=pd.read_sql(query,connection)
rows
# Out:
# C:\Users\alaaa\AppData\Local\Temp\ipykernel_3076\1957635708.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   rows=pd.read_sql(query,connection)
#       AvgPrice
# 0  1520.591402

# %% [markdown]
# ### Task 3: Retrieve the number of orders placed by each customer.

# %%
query="""select customers.customer_id,customers.first_name,count(orders.order_id) as NumOfOrders
from customers
join orders
on customers.customer_id=orders.customer_id
group by customers.first_name
"""
rows=pd.read_sql(query,connection)
rows
# Out:
# C:\Users\alaaa\AppData\Local\Temp\ipykernel_3076\4159102475.py:7: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   rows=pd.read_sql(query,connection)
#       customer_id first_name  NumOfOrders
# 0            1174      Aaron            1
# 1             338      Abbey            1
# 2              75       Abby            2
# 3            1224      Abram            1
# 4             673       Adam            2
# ...           ...        ...          ...
# 1260           81       Zina            2
# 1261         1432       Zona            1
# 1262         1052       Zora            1
# 1263          417    Zoraida            1
# 1264          630     Zulema            2
#
# [1265 rows x 3 columns]

# %% [markdown]
# ### Task 4: Join Orders with Customers

# %% [markdown]
# #### Task 4.1: Retrieve customer names along with their order IDs.

# %%
query="""select customers.first_name,customers.last_name,orders.order_id
from customers
join orders
on customers.customer_id=orders.customer_id
"""
cursor.execute(query)
rows=cursor.fetchall()
for row in rows:
    print(f"customer_first_name:{row[0]}, customer_last_name:{row[1]}, order_id:{row[2]}")
# Out:
# customer_first_name:Debra, customer_last_name:Burks, order_id:599
# customer_first_name:Debra, customer_last_name:Burks, order_id:1555
# customer_first_name:Debra, customer_last_name:Burks, order_id:1613
# customer_first_name:Kasha, customer_last_name:Todd, order_id:692
# customer_first_name:Kasha, customer_last_name:Todd, order_id:1084
# customer_first_name:Kasha, customer_last_name:Todd, order_id:1509
# customer_first_name:Tameka, customer_last_name:Fisher, order_id:1468
# customer_first_name:Tameka, customer_last_name:Fisher, order_id:1496
# customer_first_name:Tameka, customer_last_name:Fisher, order_id:1612
# customer_first_name:Daryl, customer_last_name:Spence, order_id:700
# customer_first_name:Daryl, customer_last_name:Spence, order_id:1259
# customer_first_name:Daryl, customer_last_name:Spence, order_id:1556
# customer_first_name:Charolette, customer_last_name:Rice, order_id:264
# customer_first_name:Charolette, customer_last_name:Rice, order_id:571
# customer_first_name:Charolette, customer_last_name:Rice, order_id:1544
# customer_first_name:Lyndsey, customer_last_name:Bean, order_id:1059
# customer_first_name:Lyndsey, customer_last_name:Bean, order_id:1592
# customer_first_name:Lyndsey, customer_last_name:Bean, order_id:1611
# customer_first_name:Latasha, customer_last_name:Hays, order_id:104
# customer_first_name:Latasha, customer_last_name:Hays, order_id:1532
# customer_first_name:Latasha, customer_last_name:Hays, order_id:1604
# customer_first_name:Jacquline, customer_last_name:Duncan, order_id:512
# customer_first_name:Jacquline, customer_last_name:Duncan, order_id:1010
# customer_first_name:Jacquline, customer_last_name:Duncan, order_id:1523
# customer_first_name:Genoveva, customer_last_name:Baldwin, order_id:76
# customer_first_name:Genoveva, customer_last_name:Baldwin, order_id:1459
# customer_first_name:Genoveva, customer_last_name:Baldwin, order_id:1593
# customer_first_name:Pamelia, customer_last_name:Newman, order_id:825
# customer_first_name:Pamelia, customer_last_name:Newman, order_id:1541
# customer_first_name:Pamelia, customer_last_name:Newman, order_id:1609
# customer_first_name:Deshawn, customer_last_name:Mendoza, order_id:1074
# customer_first_name:Deshawn, customer_last_name:Mendoza, order_id:1387
# customer_first_name:Deshawn, customer_last_name:Mendoza, order_id:1588
# customer_first_name:Robby, customer_last_name:Sykes, order_id:108
# customer_first_name:Robby, customer_last_name:Sykes, order_id:715
# customer_first_name:Robby, customer_last_name:Sykes, order_id:1576
# customer_first_name:Lashawn, customer_last_name:Ortiz, order_id:239
# customer_first_name:Lashawn, customer_last_name:Ortiz, order_id:852
# customer_first_name:Lashawn, customer_last_name:Ortiz, order_id:1527
# customer_first_name:Garry, customer_last_name:Espinoza, order_id:357
# customer_first_name:Garry, customer_last_name:Espinoza, order_id:419
# customer_first_name:Garry, customer_last_name:Espinoza, order_id:1572
# customer_first_name:Linnie, customer_last_name:Branch, order_id:1401
# customer_first_name:Linnie, customer_last_name:Branch, order_id:1483
# customer_first_name:Linnie, customer_last_name:Branch, order_id:1610
# customer_first_name:Emmitt, customer_last_name:Sanchez, order_id:352
# customer_first_name:Emmitt, customer_last_name:Sanchez, order_id:1020
# customer_first_name:Emmitt, customer_last_name:Sanchez, order_id:1510
# customer_first_name:Caren, customer_last_name:Stephens, order_id:246
# customer_first_name:Caren, customer_last_name:Stephens, order_id:301
# customer_first_name:Caren, customer_last_name:Stephens, order_id:1549
# customer_first_name:Georgetta, customer_last_name:Hardin, order_id:606
# customer_first_name:Georgetta, customer_last_name:Hardin, order_id:1407
# customer_first_name:Georgetta, customer_last_name:Hardin, order_id:1534
# customer_first_name:Lizzette, customer_last_name:Stein, order_id:1211
# customer_first_name:Lizzette, customer_last_name:Stein, order_id:1234
# customer_first_name:Lizzette, customer_last_name:Stein, order_id:1535
# customer_first_name:Aleta, customer_last_name:Shepard, order_id:547
# customer_first_name:Aleta, customer_last_name:Shepard, order_id:735
# customer_first_name:Aleta, customer_last_name:Shepard, order_id:1528
# customer_first_name:Tobie, customer_last_name:Little, order_id:1177
# customer_first_name:Tobie, customer_last_name:Little, order_id:1409
# customer_first_name:Tobie, customer_last_name:Little, order_id:1596
# customer_first_name:Adelle, customer_last_name:Larsen, order_id:183
# customer_first_name:Adelle, customer_last_name:Larsen, order_id:1505
# customer_first_name:Kaylee, customer_last_name:English, order_id:1109
# customer_first_name:Kaylee, customer_last_name:English, order_id:1479
# customer_first_name:Corene, customer_last_name:Wall, order_id:185
# customer_first_name:Corene, customer_last_name:Wall, order_id:1157
# customer_first_name:Corene, customer_last_name:Wall, order_id:1573
# customer_first_name:Regenia, customer_last_name:Vaughan, order_id:1065
# customer_first_name:Regenia, customer_last_name:Vaughan, order_id:1511
# customer_first_name:Theo, customer_last_name:Reese, order_id:256
# customer_first_name:Theo, customer_last_name:Reese, order_id:1519
# customer_first_name:Santos, customer_last_name:Valencia, order_id:634
# customer_first_name:Santos, customer_last_name:Valencia, order_id:1480
# customer_first_name:Jeanice, customer_last_name:Frost, order_id:1306
# customer_first_name:Jeanice, customer_last_name:Frost, order_id:1533
# customer_first_name:Syreeta, customer_last_name:Hendricks, order_id:665
# customer_first_name:Syreeta, customer_last_name:Hendricks, order_id:1569
# customer_first_name:Jamaal, customer_last_name:Albert, order_id:349
# customer_first_name:Jamaal, customer_last_name:Albert, order_id:444
# customer_first_name:Jamaal, customer_last_name:Albert, order_id:1553
# customer_first_name:Williemae, customer_last_name:Holloway, order_id:162
# customer_first_name:Williemae, customer_last_name:Holloway, order_id:350
# customer_first_name:Williemae, customer_last_name:Holloway, order_id:1497
# customer_first_name:Araceli, customer_last_name:Golden, order_id:159
# customer_first_name:Araceli, customer_last_name:Golden, order_id:582
# customer_first_name:Araceli, customer_last_name:Golden, order_id:1513
# customer_first_name:Deloris, customer_last_name:Burke, order_id:575
# customer_first_name:Deloris, customer_last_name:Burke, order_id:1487
# customer_first_name:Deloris, customer_last_name:Burke, order_id:1607
# customer_first_name:Brittney, customer_last_name:Woodward, order_id:1190
# customer_first_name:Brittney, customer_last_name:Woodward, order_id:1536
# customer_first_name:Guillermina, customer_last_name:Noble, order_id:1476
# customer_first_name:Guillermina, customer_last_name:Noble, order_id:1484
# customer_first_name:Bernita, customer_last_name:Mcdaniel, order_id:303
# customer_first_name:Bernita, customer_last_name:Mcdaniel, order_id:1537
# customer_first_name:Melia, customer_last_name:Brady, order_id:1295
# customer_first_name:Melia, customer_last_name:Brady, order_id:1524
# customer_first_name:Zelma, customer_last_name:Browning, order_id:718
# customer_first_name:Zelma, customer_last_name:Browning, order_id:1525
# customer_first_name:Janetta, customer_last_name:Aguirre, order_id:1322
# customer_first_name:Janetta, customer_last_name:Aguirre, order_id:1550
# customer_first_name:Ronna, customer_last_name:Butler, order_id:598
# customer_first_name:Ronna, customer_last_name:Butler, order_id:1092
# customer_first_name:Ronna, customer_last_name:Butler, order_id:1589
# customer_first_name:Kathie, customer_last_name:Freeman, order_id:1161
# customer_first_name:Kathie, customer_last_name:Freeman, order_id:1492
# customer_first_name:Tangela, customer_last_name:Quinn, order_id:1076
# customer_first_name:Tangela, customer_last_name:Quinn, order_id:1559
# customer_first_name:Mozelle, customer_last_name:Carter, order_id:157
# customer_first_name:Mozelle, customer_last_name:Carter, order_id:935
# customer_first_name:Mozelle, customer_last_name:Carter, order_id:1601
# customer_first_name:Onita, customer_last_name:Johns, order_id:1253
# customer_first_name:Onita, customer_last_name:Johns, order_id:1583
# customer_first_name:Bennett, customer_last_name:Armstrong, order_id:826
# customer_first_name:Bennett, customer_last_name:Armstrong, order_id:1594
# customer_first_name:Monika, customer_last_name:Berg, order_id:132
# customer_first_name:Monika, customer_last_name:Berg, order_id:1089
# customer_first_name:Monika, customer_last_name:Berg, order_id:1564
# customer_first_name:Bridgette, customer_last_name:Guerra, order_id:897
# customer_first_name:Bridgette, customer_last_name:Guerra, order_id:1072
# customer_first_name:Bridgette, customer_last_name:Guerra, order_id:1516
# customer_first_name:Cesar, customer_last_name:Jackson, order_id:1200
# customer_first_name:Cesar, customer_last_name:Jackson, order_id:1577
# customer_first_name:Caroll, customer_last_name:Hays, order_id:739
# customer_first_name:Caroll, customer_last_name:Hays, order_id:1599
# customer_first_name:Cleotilde, customer_last_name:Booth, order_id:70
# customer_first_name:Cleotilde, customer_last_name:Booth, order_id:593
# customer_first_name:Cleotilde, customer_last_name:Booth, order_id:1529
# customer_first_name:Gertrud, customer_last_name:Rhodes, order_id:222
# customer_first_name:Gertrud, customer_last_name:Rhodes, order_id:1485
# customer_first_name:Tu, customer_last_name:Ramirez, order_id:1116
# customer_first_name:Tu, customer_last_name:Ramirez, order_id:1501
# customer_first_name:Saturnina, customer_last_name:Garner, order_id:389
# customer_first_name:Saturnina, customer_last_name:Garner, order_id:1521
# customer_first_name:Saturnina, customer_last_name:Garner, order_id:1608
# customer_first_name:Fran, customer_last_name:Yang, order_id:519
# customer_first_name:Fran, customer_last_name:Yang, order_id:1570
# customer_first_name:Diana, customer_last_name:Guerra, order_id:147
# customer_first_name:Diana, customer_last_name:Guerra, order_id:1602
# customer_first_name:Lolita, customer_last_name:Mosley, order_id:778
# customer_first_name:Lolita, customer_last_name:Mosley, order_id:1413
# customer_first_name:Lolita, customer_last_name:Mosley, order_id:1597
# customer_first_name:Pamala, customer_last_name:Henry, order_id:27
# customer_first_name:Pamala, customer_last_name:Henry, order_id:1560
# customer_first_name:Damien, customer_last_name:Dorsey, order_id:694
# customer_first_name:Damien, customer_last_name:Dorsey, order_id:1542
# customer_first_name:Latasha, customer_last_name:Stanley, order_id:286
# customer_first_name:Latasha, customer_last_name:Stanley, order_id:1526
# customer_first_name:Neil, customer_last_name:Mccall, order_id:9
# customer_first_name:Neil, customer_last_name:Mccall, order_id:1565
# customer_first_name:Elinore, customer_last_name:Aguilar, order_id:391
# customer_first_name:Elinore, customer_last_name:Aguilar, order_id:556
# customer_first_name:Elinore, customer_last_name:Aguilar, order_id:1515
# customer_first_name:Alica, customer_last_name:Hunter, order_id:543
# customer_first_name:Alica, customer_last_name:Hunter, order_id:1481
# customer_first_name:Tenisha, customer_last_name:Lyons, order_id:1390
# customer_first_name:Tenisha, customer_last_name:Lyons, order_id:1558
# customer_first_name:Bobbie, customer_last_name:Foster, order_id:549
# customer_first_name:Bobbie, customer_last_name:Foster, order_id:673
# customer_first_name:Bobbie, customer_last_name:Foster, order_id:1493
# customer_first_name:Kanesha, customer_last_name:Vega, order_id:240
# customer_first_name:Kanesha, customer_last_name:Vega, order_id:1561
# customer_first_name:Lorrie, customer_last_name:Becker, order_id:252
# customer_first_name:Lorrie, customer_last_name:Becker, order_id:885
# customer_first_name:Lorrie, customer_last_name:Becker, order_id:1520
# customer_first_name:Tommie, customer_last_name:Melton, order_id:424
# customer_first_name:Tommie, customer_last_name:Melton, order_id:1545
# customer_first_name:Jayne, customer_last_name:Kirkland, order_id:924
# customer_first_name:Jayne, customer_last_name:Kirkland, order_id:1325
# customer_first_name:Jayne, customer_last_name:Kirkland, order_id:1512
# customer_first_name:Katelin, customer_last_name:Kennedy, order_id:1130
# customer_first_name:Katelin, customer_last_name:Kennedy, order_id:1494
# customer_first_name:Tomasa, customer_last_name:Carson, order_id:1041
# customer_first_name:Tomasa, customer_last_name:Carson, order_id:1551
# customer_first_name:Takako, customer_last_name:Casey, order_id:1360
# customer_first_name:Takako, customer_last_name:Casey, order_id:1595
# customer_first_name:Petronila, customer_last_name:Norris, order_id:420
# customer_first_name:Petronila, customer_last_name:Norris, order_id:1566
# customer_first_name:Melanie, customer_last_name:Hayes, order_id:937
# customer_first_name:Melanie, customer_last_name:Hayes, order_id:1552
# customer_first_name:Georgeann, customer_last_name:Waller, order_id:464
# customer_first_name:Georgeann, customer_last_name:Waller, order_id:1603
# customer_first_name:Abby, customer_last_name:Gamble, order_id:1318
# customer_first_name:Abby, customer_last_name:Gamble, order_id:1506
# customer_first_name:Parker, customer_last_name:Prince, order_id:152
# customer_first_name:Parker, customer_last_name:Prince, order_id:1543
# customer_first_name:Keri, customer_last_name:Bridges, order_id:407
# customer_first_name:Keri, customer_last_name:Bridges, order_id:435
# customer_first_name:Keri, customer_last_name:Bridges, order_id:1563
# customer_first_name:Chi, customer_last_name:Goff, order_id:801
# customer_first_name:Chi, customer_last_name:Goff, order_id:1522
# customer_first_name:Ashanti, customer_last_name:Parks, order_id:707
# customer_first_name:Ashanti, customer_last_name:Parks, order_id:1538
# customer_first_name:Sarai, customer_last_name:Mckee, order_id:34
# customer_first_name:Sarai, customer_last_name:Mckee, order_id:1571
# customer_first_name:Zina, customer_last_name:Bonner, order_id:679
# customer_first_name:Zina, customer_last_name:Bonner, order_id:1498
# customer_first_name:Lizzie, customer_last_name:Joyner, order_id:961
# customer_first_name:Lizzie, customer_last_name:Joyner, order_id:1491
# customer_first_name:Tiesha, customer_last_name:Daniel, order_id:327
# customer_first_name:Tiesha, customer_last_name:Daniel, order_id:1502
# customer_first_name:Armand, customer_last_name:Whitehead, order_id:129
# customer_first_name:Armand, customer_last_name:Whitehead, order_id:1486
# customer_first_name:Teofila, customer_last_name:Fischer, order_id:1283
# customer_first_name:Teofila, customer_last_name:Fischer, order_id:1507
# customer_first_name:Lissa, customer_last_name:Vargas, order_id:128
# customer_first_name:Lissa, customer_last_name:Vargas, order_id:1495
# customer_first_name:Yan, customer_last_name:Mcgowan, order_id:747
# customer_first_name:Yan, customer_last_name:Mcgowan, order_id:1514
# customer_first_name:Titus, customer_last_name:Bullock, order_id:418
# customer_first_name:Titus, customer_last_name:Bullock, order_id:1562
# customer_first_name:Arvilla, customer_last_name:Osborn, order_id:1229
# customer_first_name:Arvilla, customer_last_name:Osborn, order_id:1567
# customer_first_name:Marjorie, customer_last_name:Logan, order_id:561
# customer_first_name:Marjorie, customer_last_name:Logan, order_id:1600
# customer_first_name:Marvin, customer_last_name:Mullins, order_id:12
# customer_first_name:Marvin, customer_last_name:Mullins, order_id:1546
# customer_first_name:Tena, customer_last_name:Cruz, order_id:1369
# customer_first_name:Tena, customer_last_name:Cruz, order_id:1508
# customer_first_name:Corrina, customer_last_name:Sawyer, order_id:934
# customer_first_name:Corrina, customer_last_name:Sawyer, order_id:1578
# customer_first_name:Sharyn, customer_last_name:Hopkins, order_id:6
# customer_first_name:Sharyn, customer_last_name:Hopkins, order_id:1482
# customer_first_name:Letitia, customer_last_name:Franco, order_id:804
# customer_first_name:Floretta, customer_last_name:Higgins, order_id:604
# customer_first_name:Louanne, customer_last_name:Martin, order_id:867
# customer_first_name:Louanne, customer_last_name:Martin, order_id:1517
# customer_first_name:Violet, customer_last_name:Valenzuela, order_id:190
# customer_first_name:Carie, customer_last_name:Kidd, order_id:169
# customer_first_name:Kellie, customer_last_name:Franco, order_id:1405
# customer_first_name:Nichelle, customer_last_name:Howell, order_id:448
# customer_first_name:Marisol, customer_last_name:Goodman, order_id:588
# customer_first_name:Sylvie, customer_last_name:Wilkerson, order_id:401
# customer_first_name:Katharina, customer_last_name:Bates, order_id:554
# customer_first_name:Katharina, customer_last_name:Bates, order_id:1579
# customer_first_name:Marget, customer_last_name:Hodge, order_id:207
# customer_first_name:Raul, customer_last_name:Melendez, order_id:1066
# customer_first_name:Cecil, customer_last_name:Hopper, order_id:258
# customer_first_name:Shae, customer_last_name:Hickman, order_id:1297
# customer_first_name:Monica, customer_last_name:Sears, order_id:1411
# customer_first_name:Monica, customer_last_name:Sears, order_id:1584
# customer_first_name:Ollie, customer_last_name:Zimmerman, order_id:1252
# customer_first_name:Ollie, customer_last_name:Zimmerman, order_id:1530
# customer_first_name:Shila, customer_last_name:White, order_id:516
# customer_first_name:Yuk, customer_last_name:Vega, order_id:1475
# customer_first_name:Eliana, customer_last_name:Silva, order_id:1264
# customer_first_name:Thalia, customer_last_name:Horne, order_id:1472
# customer_first_name:Rey, customer_last_name:Lindsay, order_id:1370
# customer_first_name:Merlene, customer_last_name:Vinson, order_id:531
# customer_first_name:Merlene, customer_last_name:Vinson, order_id:1047
# customer_first_name:Merlene, customer_last_name:Vinson, order_id:1539
# customer_first_name:Dacia, customer_last_name:William, order_id:158
# customer_first_name:Dacia, customer_last_name:William, order_id:173
# customer_first_name:Le, customer_last_name:Wood, order_id:617
# customer_first_name:Thalia, customer_last_name:Dillard, order_id:741
# customer_first_name:Thalia, customer_last_name:Dillard, order_id:1606
# customer_first_name:Luz, customer_last_name:House, order_id:907
# customer_first_name:Luz, customer_last_name:House, order_id:1499
# customer_first_name:Lucy, customer_last_name:Woods, order_id:177
# customer_first_name:Lucy, customer_last_name:Woods, order_id:1557
# customer_first_name:Shena, customer_last_name:Carter, order_id:1364
# customer_first_name:Robena, customer_last_name:Hill, order_id:1280
# customer_first_name:Robena, customer_last_name:Hill, order_id:1605
# customer_first_name:Jeni, customer_last_name:Booker, order_id:738
# customer_first_name:Jeni, customer_last_name:Booker, order_id:1574
# customer_first_name:Herlinda, customer_last_name:Stone, order_id:1021
# customer_first_name:Lavina, customer_last_name:Dejesus, order_id:1425
# customer_first_name:Erlinda, customer_last_name:Nielsen, order_id:197
# customer_first_name:Terrance, customer_last_name:Lynn, order_id:1284
# customer_first_name:Walton, customer_last_name:Dejesus, order_id:938
# customer_first_name:Wes, customer_last_name:Stanton, order_id:626
# customer_first_name:Tanesha, customer_last_name:Hampton, order_id:618
# customer_first_name:Boyd, customer_last_name:Irwin, order_id:372
# customer_first_name:Delbert, customer_last_name:Wilkins, order_id:287
# customer_first_name:Brianna, customer_last_name:Moss, order_id:184
# customer_first_name:Dorthey, customer_last_name:Jackson, order_id:770
# customer_first_name:Dorthey, customer_last_name:Jackson, order_id:1614
# customer_first_name:Sarita, customer_last_name:Parks, order_id:1346
# customer_first_name:Sarita, customer_last_name:Parks, order_id:1615
# customer_first_name:Shonta, customer_last_name:Mercer, order_id:743
# customer_first_name:Jone, customer_last_name:Bernard, order_id:944
# customer_first_name:Jone, customer_last_name:Bernard, order_id:1590
# customer_first_name:Wanita, customer_last_name:Davenport, order_id:1461
# customer_first_name:Cleopatra, customer_last_name:Tate, order_id:1055
# customer_first_name:Ramiro, customer_last_name:Byers, order_id:766
# customer_first_name:Nicholas, customer_last_name:Vazquez, order_id:950
# customer_first_name:Janae, customer_last_name:Doyle, order_id:1121
# customer_first_name:Hans, customer_last_name:Price, order_id:395
# customer_first_name:Miquel, customer_last_name:Neal, order_id:249
# customer_first_name:Stefany, customer_last_name:Potter, order_id:1399
# customer_first_name:Bernetta, customer_last_name:Marquez, order_id:732
# customer_first_name:Julee, customer_last_name:Woodard, order_id:500
# customer_first_name:Meredith, customer_last_name:Bryan, order_id:439
# customer_first_name:Weldon, customer_last_name:Michael, order_id:250
# customer_first_name:Joesph, customer_last_name:Delacruz, order_id:60
# customer_first_name:Joesph, customer_last_name:Delacruz, order_id:1500
# customer_first_name:Katherina, customer_last_name:Odom, order_id:1467
# customer_first_name:Laraine, customer_last_name:Robbins, order_id:429
# customer_first_name:Laraine, customer_last_name:Robbins, order_id:810
# customer_first_name:Jenise, customer_last_name:Preston, order_id:796
# customer_first_name:Lory, customer_last_name:Page, order_id:513
# customer_first_name:Charlyn, customer_last_name:Cantrell, order_id:308
# customer_first_name:Carola, customer_last_name:Rodriquez, order_id:224
# customer_first_name:Carola, customer_last_name:Rodriquez, order_id:1585
# customer_first_name:Alane, customer_last_name:Kennedy, order_id:291
# customer_first_name:Regina, customer_last_name:Burns, order_id:282
# customer_first_name:Omer, customer_last_name:Estrada, order_id:579
# customer_first_name:Crystle, customer_last_name:Gilliam, order_id:1030
# customer_first_name:Kam, customer_last_name:Wilder, order_id:858
# customer_first_name:Margert, customer_last_name:Stevens, order_id:632
# customer_first_name:Tomika, customer_last_name:Larson, order_id:37
# customer_first_name:Jeromy, customer_last_name:Burch, order_id:1275
# customer_first_name:Jeromy, customer_last_name:Burch, order_id:1591
# customer_first_name:Lena, customer_last_name:Mills, order_id:744
# customer_first_name:Loreta, customer_last_name:Johnston, order_id:945
# customer_first_name:Nettie, customer_last_name:Mcdaniel, order_id:1017
# customer_first_name:Karla, customer_last_name:Kirk, order_id:432
# customer_first_name:Karla, customer_last_name:Kirk, order_id:1547
# customer_first_name:Regine, customer_last_name:Gonzales, order_id:142
# customer_first_name:Regine, customer_last_name:Gonzales, order_id:1548
# customer_first_name:Miriam, customer_last_name:Baker, order_id:890
# customer_first_name:Jeanie, customer_last_name:Kirkland, order_id:987
# customer_first_name:Jeanie, customer_last_name:Kirkland, order_id:1554
# customer_first_name:Marquerite, customer_last_name:Dawson, order_id:712
# customer_first_name:Babara, customer_last_name:Ochoa, order_id:1013
# customer_first_name:Nova, customer_last_name:Hess, order_id:4
# customer_first_name:Nova, customer_last_name:Hess, order_id:1518
# customer_first_name:Carley, customer_last_name:Reynolds, order_id:392
# customer_first_name:Carley, customer_last_name:Reynolds, order_id:1586
# customer_first_name:Carissa, customer_last_name:Foreman, order_id:854
# customer_first_name:Genoveva, customer_last_name:Tyler, order_id:572
# customer_first_name:Deane, customer_last_name:Sears, order_id:903
# customer_first_name:Karey, customer_last_name:Steele, order_id:1477
# customer_first_name:Olevia, customer_last_name:Pitts, order_id:283
# customer_first_name:Olevia, customer_last_name:Pitts, order_id:1488
# customer_first_name:Jenniffer, customer_last_name:Bullock, order_id:1060
# customer_first_name:Jeniffer, customer_last_name:Ratliff, order_id:187
# customer_first_name:Klara, customer_last_name:Stanley, order_id:736
# customer_first_name:Morton, customer_last_name:Lee, order_id:1045
# customer_first_name:Ken, customer_last_name:Charles, order_id:1191
# customer_first_name:Hedwig, customer_last_name:Paul, order_id:362
# customer_first_name:Hedwig, customer_last_name:Paul, order_id:1540
# customer_first_name:Sharla, customer_last_name:Flynn, order_id:909
# customer_first_name:Sharla, customer_last_name:Flynn, order_id:1581
# customer_first_name:Damian, customer_last_name:Dawson, order_id:1054
# customer_first_name:Toya, customer_last_name:Pratt, order_id:651
# customer_first_name:Graciela, customer_last_name:Barber, order_id:492
# customer_first_name:Graciela, customer_last_name:Barber, order_id:1580
# customer_first_name:Bong, customer_last_name:Hebert, order_id:1194
# customer_first_name:Bong, customer_last_name:Hebert, order_id:1568
# customer_first_name:Ayanna, customer_last_name:Rhodes, order_id:496
# customer_first_name:Dorine, customer_last_name:Roberson, order_id:1049
# customer_first_name:Dorine, customer_last_name:Roberson, order_id:1489
# customer_first_name:Addie, customer_last_name:Hahn, order_id:1428
# customer_first_name:Edythe, customer_last_name:Valencia, order_id:882
# customer_first_name:Andy, customer_last_name:O'neill, order_id:458
# customer_first_name:Luis, customer_last_name:Tyler, order_id:1063
# customer_first_name:Clelia, customer_last_name:Workman, order_id:382
# customer_first_name:Ashely, customer_last_name:Holmes, order_id:719
# customer_first_name:Candis, customer_last_name:Harding, order_id:1201
# customer_first_name:Marni, customer_last_name:Bolton, order_id:290
# customer_first_name:Minerva, customer_last_name:Decker, order_id:1333
# customer_first_name:Alpha, customer_last_name:King, order_id:97
# customer_first_name:Harris, customer_last_name:Pittman, order_id:160
# customer_first_name:Stephaine, customer_last_name:Riddle, order_id:236
# customer_first_name:Michel, customer_last_name:Blankenship, order_id:713
# customer_first_name:Denis, customer_last_name:Logan, order_id:62
# customer_first_name:Denis, customer_last_name:Logan, order_id:1503
# customer_first_name:Jutta, customer_last_name:Everett, order_id:1051
# customer_first_name:Priscilla, customer_last_name:Wilkins, order_id:1235
# customer_first_name:Gilma, customer_last_name:Dejesus, order_id:309
# customer_first_name:Buford, customer_last_name:Bridges, order_id:555
# customer_first_name:Elenore, customer_last_name:Hensley, order_id:1212
# customer_first_name:Ross, customer_last_name:Pugh, order_id:879
# customer_first_name:Judith, customer_last_name:Finley, order_id:915
# customer_first_name:Wai, customer_last_name:Soto, order_id:1183
# customer_first_name:Carline, customer_last_name:Collier, order_id:1321
# customer_first_name:Carline, customer_last_name:Collier, order_id:1490
# customer_first_name:Casey, customer_last_name:Gill, order_id:95
# customer_first_name:Darcie, customer_last_name:Morgan, order_id:998
# customer_first_name:Lucio, customer_last_name:Sherman, order_id:1086
# customer_first_name:Clementine, customer_last_name:Mooney, order_id:819
# customer_first_name:Anya, customer_last_name:Contreras, order_id:1206
# customer_first_name:Scarlet, customer_last_name:Yates, order_id:245
# customer_first_name:Moses, customer_last_name:Pope, order_id:878
# customer_first_name:Moses, customer_last_name:Pope, order_id:1575
# customer_first_name:Barbera, customer_last_name:Riggs, order_id:1067
# customer_first_name:Kiana, customer_last_name:Rivera, order_id:1226
# customer_first_name:Danielle, customer_last_name:Bond, order_id:1277
# customer_first_name:Whitney, customer_last_name:Estes, order_id:1448
# customer_first_name:Molly, customer_last_name:Langley, order_id:1195
# customer_first_name:Chelsey, customer_last_name:Hardin, order_id:304
# customer_first_name:Jenee, customer_last_name:Rasmussen, order_id:1296
# customer_first_name:Jenee, customer_last_name:Rasmussen, order_id:1587
# customer_first_name:Freddie, customer_last_name:Mathis, order_id:750
# customer_first_name:Mariana, customer_last_name:Strong, order_id:926
# customer_first_name:Mariana, customer_last_name:Strong, order_id:1531
# customer_first_name:Winfred, customer_last_name:Harris, order_id:806
# customer_first_name:Jeromy, customer_last_name:Elliott, order_id:509
# customer_first_name:Verona, customer_last_name:O'neill, order_id:33
# customer_first_name:Elvera, customer_last_name:Peck, order_id:171
# customer_first_name:Elvera, customer_last_name:Peck, order_id:1504
# customer_first_name:Cindi, customer_last_name:Larson, order_id:973
# customer_first_name:Felice, customer_last_name:Guzman, order_id:1050
# customer_first_name:Felice, customer_last_name:Guzman, order_id:1598
# customer_first_name:Le, customer_last_name:Deleon, order_id:421
# customer_first_name:Le, customer_last_name:Deleon, order_id:1582
# customer_first_name:Manie, customer_last_name:Sanchez, order_id:475
# customer_first_name:Rutha, customer_last_name:Howell, order_id:918
# customer_first_name:Natosha, customer_last_name:Rowland, order_id:1236
# customer_first_name:Jessika, customer_last_name:Bray, order_id:1320
# customer_first_name:Delila, customer_last_name:Hamilton, order_id:680
# customer_first_name:Dionne, customer_last_name:Norris, order_id:828
# customer_first_name:Muriel, customer_last_name:Juarez, order_id:1347
# customer_first_name:Cecelia, customer_last_name:Gill, order_id:969
# customer_first_name:Magda, customer_last_name:Eaton, order_id:786
# customer_first_name:Ivonne, customer_last_name:Yang, order_id:678
# customer_first_name:Kasie, customer_last_name:Rodriquez, order_id:161
# customer_first_name:Eleni, customer_last_name:Gordon, order_id:28
# customer_first_name:Maurice, customer_last_name:Norton, order_id:1358
# customer_first_name:Cristobal, customer_last_name:Hutchinson, order_id:1138
# customer_first_name:Flossie, customer_last_name:Holder, order_id:749
# customer_first_name:Erma, customer_last_name:Salinas, order_id:1332
# customer_first_name:Earl, customer_last_name:Stanley, order_id:1305
# customer_first_name:Maribel, customer_last_name:William, order_id:14
# customer_first_name:Johnathan, customer_last_name:Velazquez, order_id:1
# customer_first_name:Rodrick, customer_last_name:Shelton, order_id:499
# customer_first_name:Ferne, customer_last_name:Kline, order_id:411
# customer_first_name:Rubin, customer_last_name:Decker, order_id:1285
# customer_first_name:Dortha, customer_last_name:Jarvis, order_id:1438
# customer_first_name:Mariela, customer_last_name:Huffman, order_id:74
# customer_first_name:Mellisa, customer_last_name:Farley, order_id:936
# customer_first_name:Myung, customer_last_name:Hooper, order_id:1005
# customer_first_name:Angelina, customer_last_name:Lloyd, order_id:216
# customer_first_name:Trinity, customer_last_name:Riddle, order_id:1104
# customer_first_name:Barton, customer_last_name:Crosby, order_id:1197
# customer_first_name:Claudio, customer_last_name:Wise, order_id:972
# customer_first_name:Katheleen, customer_last_name:Marks, order_id:101
# customer_first_name:Deja, customer_last_name:Chaney, order_id:430
# customer_first_name:Queenie, customer_last_name:Vance, order_id:1323
# customer_first_name:Josh, customer_last_name:Shaw, order_id:329
# customer_first_name:Pinkie, customer_last_name:Kirkland, order_id:1124
# customer_first_name:Lavette, customer_last_name:Wright, order_id:86
# customer_first_name:Mark, customer_last_name:Garrett, order_id:61
# customer_first_name:Myesha, customer_last_name:Burgess, order_id:947
# customer_first_name:Justina, customer_last_name:Long, order_id:1287
# customer_first_name:Brenda, customer_last_name:Tate, order_id:201
# customer_first_name:Rayna, customer_last_name:Perry, order_id:299
# customer_first_name:Randolph, customer_last_name:Chase, order_id:267
# customer_first_name:Jaimee, customer_last_name:Day, order_id:647
# customer_first_name:Susann, customer_last_name:Bass, order_id:759
# customer_first_name:Leola, customer_last_name:Gould, order_id:1292
# customer_first_name:Virgil, customer_last_name:Frost, order_id:1166
# customer_first_name:Mireille, customer_last_name:Puckett, order_id:1452
# customer_first_name:Keturah, customer_last_name:Massey, order_id:146
# customer_first_name:Charmain, customer_last_name:Webster, order_id:1251
# customer_first_name:Barry, customer_last_name:Buckner, order_id:1018
# customer_first_name:Boyce, customer_last_name:Burks, order_id:675
# customer_first_name:Monty, customer_last_name:Frost, order_id:1175
# customer_first_name:Tiny, customer_last_name:French, order_id:1414
# customer_first_name:Clementina, customer_last_name:Sargent, order_id:822
# customer_first_name:Danny, customer_last_name:Kim, order_id:710
# customer_first_name:Sophia, customer_last_name:Mcmillan, order_id:1450
# customer_first_name:Christia, customer_last_name:Carson, order_id:668
# customer_first_name:Jennie, customer_last_name:Middleton, order_id:566
# customer_first_name:Jame, customer_last_name:Riggs, order_id:312
# customer_first_name:Rayford, customer_last_name:Simon, order_id:1417
# customer_first_name:Annett, customer_last_name:Garrett, order_id:817
# customer_first_name:Hayden, customer_last_name:Cross, order_id:1473
# customer_first_name:Rolanda, customer_last_name:Larsen, order_id:1242
# customer_first_name:Jayme, customer_last_name:Zamora, order_id:478
# customer_first_name:Hope, customer_last_name:Cotton, order_id:1085
# customer_first_name:Vikki, customer_last_name:Erickson, order_id:105
# customer_first_name:Fransisca, customer_last_name:Nicholson, order_id:225
# customer_first_name:Mazie, customer_last_name:Fernandez, order_id:1431
# customer_first_name:Anderson, customer_last_name:Martin, order_id:607
# customer_first_name:Gilberto, customer_last_name:Parsons, order_id:1362
# customer_first_name:Charise, customer_last_name:Burt, order_id:1312
# customer_first_name:Cameron, customer_last_name:Carroll, order_id:1375
# customer_first_name:Melani, customer_last_name:Jarvis, order_id:542
# customer_first_name:Javier, customer_last_name:Nichols, order_id:438
# customer_first_name:Justina, customer_last_name:Jenkins, order_id:808
# customer_first_name:Hortencia, customer_last_name:Graham, order_id:131
# customer_first_name:Christia, customer_last_name:Wilkins, order_id:84
# customer_first_name:Eliz, customer_last_name:Whitney, order_id:1199
# customer_first_name:Justin, customer_last_name:Newton, order_id:285
# customer_first_name:Aron, customer_last_name:Wiggins, order_id:1282
# customer_first_name:Chere, customer_last_name:Hardin, order_id:544
# customer_first_name:Merideth, customer_last_name:Preston, order_id:1302
# customer_first_name:Jeniffer, customer_last_name:Slater, order_id:1388
# customer_first_name:Laureen, customer_last_name:Paul, order_id:7
# customer_first_name:Berna, customer_last_name:Moore, order_id:1056
# customer_first_name:Shiela, customer_last_name:Calderon, order_id:1093
# customer_first_name:Sharie, customer_last_name:Alvarez, order_id:120
# customer_first_name:Bettie, customer_last_name:Glover, order_id:980
# customer_first_name:Marilyn, customer_last_name:Frank, order_id:847
# customer_first_name:Sheba, customer_last_name:Knapp, order_id:1449
# customer_first_name:Aleta, customer_last_name:Mack, order_id:383
# customer_first_name:Reena, customer_last_name:Higgins, order_id:150
# customer_first_name:Ami, customer_last_name:Mcmahon, order_id:1244
# customer_first_name:Somer, customer_last_name:Jordan, order_id:1117
# customer_first_name:Scarlet, customer_last_name:Reed, order_id:752
# customer_first_name:Trisha, customer_last_name:Johnson, order_id:102
# customer_first_name:Majorie, customer_last_name:Wyatt, order_id:373
# customer_first_name:Abbey, customer_last_name:Pugh, order_id:166
# customer_first_name:Tamela, customer_last_name:Harrell, order_id:951
# customer_first_name:Yanira, customer_last_name:Bradshaw, order_id:802
# customer_first_name:Delana, customer_last_name:Scott, order_id:538
# customer_first_name:Cassondra, customer_last_name:Pruitt, order_id:910
# customer_first_name:Jesica, customer_last_name:Fields, order_id:688
# customer_first_name:Herta, customer_last_name:Rollins, order_id:663
# customer_first_name:Mi, customer_last_name:Gray, order_id:901
# customer_first_name:Jacalyn, customer_last_name:Barnett, order_id:1243
# customer_first_name:Kanesha, customer_last_name:Hudson, order_id:655
# customer_first_name:Darren, customer_last_name:Witt, order_id:40
# customer_first_name:Mable, customer_last_name:Pratt, order_id:657
# customer_first_name:Christoper, customer_last_name:Mccall, order_id:271
# customer_first_name:Margorie, customer_last_name:Wynn, order_id:1132
# customer_first_name:Josef, customer_last_name:Greer, order_id:898
# customer_first_name:Tisa, customer_last_name:Whitney, order_id:1022
# customer_first_name:Tonda, customer_last_name:Armstrong, order_id:1001
# customer_first_name:Arvilla, customer_last_name:Weiss, order_id:952
# customer_first_name:Vashti, customer_last_name:Rosario, order_id:1023
# customer_first_name:Sheri, customer_last_name:Cole, order_id:156
# customer_first_name:Kandace, customer_last_name:Giles, order_id:871
# customer_first_name:Angie, customer_last_name:Powers, order_id:417
# customer_first_name:Van, customer_last_name:Peters, order_id:292
# customer_first_name:Virgina, customer_last_name:Berg, order_id:670
# customer_first_name:Olevia, customer_last_name:Noel, order_id:445
# customer_first_name:Kaci, customer_last_name:Gallegos, order_id:214
# customer_first_name:Bev, customer_last_name:Chang, order_id:1418
# customer_first_name:Rodger, customer_last_name:Rojas, order_id:563
# customer_first_name:Lavonne, customer_last_name:Anderson, order_id:145
# customer_first_name:Blanca, customer_last_name:Hooper, order_id:779
# customer_first_name:Alysha, customer_last_name:Powers, order_id:393
# customer_first_name:Mary, customer_last_name:Singleton, order_id:1184
# customer_first_name:Jina, customer_last_name:Cooper, order_id:137
# customer_first_name:Loni, customer_last_name:Duncan, order_id:155
# customer_first_name:Collene, customer_last_name:Roman, order_id:840
# customer_first_name:Mariette, customer_last_name:Trevino, order_id:364
# customer_first_name:Candelaria, customer_last_name:Coffey, order_id:797
# customer_first_name:Yan, customer_last_name:Trevino, order_id:1255
# customer_first_name:Elanor, customer_last_name:Patrick, order_id:896
# customer_first_name:Klara, customer_last_name:Mosley, order_id:511
# customer_first_name:Rosalba, customer_last_name:O'neal, order_id:279
# customer_first_name:Mina, customer_last_name:Carrillo, order_id:1101
# customer_first_name:Alesia, customer_last_name:Horne, order_id:686
# customer_first_name:Kristen, customer_last_name:Alvarez, order_id:68
# customer_first_name:Collin, customer_last_name:Webster, order_id:720
# customer_first_name:Ashlee, customer_last_name:Pena, order_id:660
# customer_first_name:Aimee, customer_last_name:Merritt, order_id:891
# customer_first_name:Rochelle, customer_last_name:Ward, order_id:77
# customer_first_name:Nelle, customer_last_name:Beck, order_id:875
# customer_first_name:Kaila, customer_last_name:Walters, order_id:1266
# customer_first_name:Aleta, customer_last_name:Stone, order_id:1113
# customer_first_name:Leif, customer_last_name:Short, order_id:966
# customer_first_name:Lorrie, customer_last_name:Pollard, order_id:188
# customer_first_name:Vernita, customer_last_name:Ball, order_id:746
# customer_first_name:Cyndi, customer_last_name:Bush, order_id:1478
# customer_first_name:Gertrude, customer_last_name:Terry, order_id:83
# customer_first_name:Virgen, customer_last_name:Clemons, order_id:872
# customer_first_name:Fairy, customer_last_name:Robinson, order_id:1454
# customer_first_name:Laverna, customer_last_name:Hernandez, order_id:404
# customer_first_name:Jeannie, customer_last_name:Wilcox, order_id:80
# customer_first_name:Suellen, customer_last_name:Mercado, order_id:422
# customer_first_name:Bart, customer_last_name:Hess, order_id:446
# customer_first_name:Alfredo, customer_last_name:Dodson, order_id:977
# customer_first_name:Shaunda, customer_last_name:Barnett, order_id:502
# customer_first_name:Kerrie, customer_last_name:Morton, order_id:908
# customer_first_name:Elouise, customer_last_name:Fry, order_id:124
# customer_first_name:Augustus, customer_last_name:Steele, order_id:964
# customer_first_name:Greta, customer_last_name:Page, order_id:1455
# customer_first_name:Kerrie, customer_last_name:O'neill, order_id:833
# customer_first_name:Dannette, customer_last_name:Guerrero, order_id:1029
# customer_first_name:Edra, customer_last_name:Fitzgerald, order_id:1019
# customer_first_name:Jerome, customer_last_name:Bolton, order_id:133
# customer_first_name:Conception, customer_last_name:Slater, order_id:384
# customer_first_name:Octavia, customer_last_name:Case, order_id:274
# customer_first_name:Dexter, customer_last_name:Roberts, order_id:1077
# customer_first_name:Ginette, customer_last_name:Edwards, order_id:259
# customer_first_name:Romaine, customer_last_name:Haley, order_id:90
# customer_first_name:Gwendolyn, customer_last_name:Miller, order_id:823
# customer_first_name:Luke, customer_last_name:Fuller, order_id:409
# customer_first_name:Zoraida, customer_last_name:Patton, order_id:703
# customer_first_name:Georgeanna, customer_last_name:Webster, order_id:1317
# customer_first_name:Krystin, customer_last_name:Marshall, order_id:994
# customer_first_name:Vince, customer_last_name:Schneider, order_id:805
# customer_first_name:Iola, customer_last_name:Rasmussen, order_id:484
# customer_first_name:Valery, customer_last_name:Saunders, order_id:106
# customer_first_name:Johna, customer_last_name:Powers, order_id:573
# customer_first_name:Charleen, customer_last_name:Hurst, order_id:306
# customer_first_name:Augustina, customer_last_name:Joyner, order_id:1334
# customer_first_name:Daisy, customer_last_name:Ward, order_id:1247
# customer_first_name:Latonya, customer_last_name:Dixon, order_id:1373
# customer_first_name:Hipolito, customer_last_name:Padilla, order_id:841
# customer_first_name:Emmett, customer_last_name:Casey, order_id:1032
# customer_first_name:Kandi, customer_last_name:Mcneil, order_id:784
# customer_first_name:Luciano, customer_last_name:Marsh, order_id:830
# customer_first_name:Julius, customer_last_name:Holt, order_id:791
# customer_first_name:Holly, customer_last_name:Nieves, order_id:742
# customer_first_name:Douglass, customer_last_name:Little, order_id:427
# customer_first_name:Izola, customer_last_name:Hobbs, order_id:1261
# customer_first_name:Honey, customer_last_name:Camacho, order_id:988
# customer_first_name:Laureen, customer_last_name:Barry, order_id:29
# customer_first_name:Katharine, customer_last_name:Herrera, order_id:138
# customer_first_name:Sunshine, customer_last_name:Rosario, order_id:644
# customer_first_name:Yevette, customer_last_name:Todd, order_id:1357
# customer_first_name:Dorthea, customer_last_name:Walker, order_id:359
# customer_first_name:Alane, customer_last_name:Munoz, order_id:10
# customer_first_name:Ayana, customer_last_name:Keith, order_id:1329
# customer_first_name:Caridad, customer_last_name:Compton, order_id:1310
# customer_first_name:Earline, customer_last_name:Ballard, order_id:577
# customer_first_name:Nathanael, customer_last_name:Bradley, order_id:863
# customer_first_name:Chasidy, customer_last_name:Tran, order_id:398
# customer_first_name:Janella, customer_last_name:Bright, order_id:772
# customer_first_name:Josie, customer_last_name:Schultz, order_id:477
# customer_first_name:Ellsworth, customer_last_name:Michael, order_id:15
# customer_first_name:Jennette, customer_last_name:Wooten, order_id:387
# customer_first_name:Cassandra, customer_last_name:Nichols, order_id:1403
# customer_first_name:Courtney, customer_last_name:Wyatt, order_id:1068
# customer_first_name:Terese, customer_last_name:Palmer, order_id:619
# customer_first_name:Sherita, customer_last_name:Cherry, order_id:836
# customer_first_name:Serina, customer_last_name:Hensley, order_id:1057
# customer_first_name:Jeni, customer_last_name:Farley, order_id:965
# customer_first_name:Everett, customer_last_name:Vega, order_id:1256
# customer_first_name:Latosha, customer_last_name:Dalton, order_id:181
# customer_first_name:Romelia, customer_last_name:Myers, order_id:1052
# customer_first_name:Effie, customer_last_name:Jenkins, order_id:985
# customer_first_name:Efren, customer_last_name:Oliver, order_id:1233
# customer_first_name:Jerlene, customer_last_name:Rios, order_id:1439
# customer_first_name:Bess, customer_last_name:Mcbride, order_id:1349
# customer_first_name:Birdie, customer_last_name:Kramer, order_id:485
# customer_first_name:Collen, customer_last_name:Hayes, order_id:620
# customer_first_name:Clare, customer_last_name:Neal, order_id:1267
# customer_first_name:Jeanett, customer_last_name:Herman, order_id:472
# customer_first_name:Micki, customer_last_name:Rutledge, order_id:112
# customer_first_name:Loise, customer_last_name:Walker, order_id:546
# customer_first_name:Burma, customer_last_name:Summers, order_id:116
# customer_first_name:Myron, customer_last_name:Ruiz, order_id:929
# customer_first_name:Lashawna, customer_last_name:Richardson, order_id:860
# customer_first_name:Lavern, customer_last_name:Orr, order_id:1419
# customer_first_name:Alec, customer_last_name:Peck, order_id:378
# customer_first_name:Christopher, customer_last_name:Richardson, order_id:1354
# customer_first_name:Arminda, customer_last_name:Weber, order_id:856
# customer_first_name:Emmett, customer_last_name:Hahn, order_id:1442
# customer_first_name:Gertha, customer_last_name:Mejia, order_id:792
# customer_first_name:Garland, customer_last_name:Weaver, order_id:324
# customer_first_name:Jayson, customer_last_name:Rutledge, order_id:481
# customer_first_name:Narcisa, customer_last_name:Knapp, order_id:1222
# customer_first_name:Gayla, customer_last_name:Sims, order_id:1432
# customer_first_name:Chelsey, customer_last_name:Boyd, order_id:127
# customer_first_name:Catherine, customer_last_name:Miles, order_id:997
# customer_first_name:Valeri, customer_last_name:Marshall, order_id:1187
# customer_first_name:Grace, customer_last_name:Madden, order_id:587
# customer_first_name:Joaquin, customer_last_name:Hawkins, order_id:1383
# customer_first_name:Kirstie, customer_last_name:Vazquez, order_id:227
# customer_first_name:Yu, customer_last_name:Mcdonald, order_id:776
# customer_first_name:Celestine, customer_last_name:Jacobs, order_id:1389
# customer_first_name:Justa, customer_last_name:Thompson, order_id:449
# customer_first_name:Lise, customer_last_name:Alvarado, order_id:1069
# customer_first_name:Pearl, customer_last_name:Fox, order_id:1127
# customer_first_name:Travis, customer_last_name:Goodman, order_id:1011
# customer_first_name:Shu, customer_last_name:Mays, order_id:777
# customer_first_name:Ezra, customer_last_name:Fowler, order_id:272
# customer_first_name:Edda, customer_last_name:Young, order_id:153
# customer_first_name:Lidia, customer_last_name:Ashley, order_id:681
# customer_first_name:Moira, customer_last_name:Lester, order_id:730
# customer_first_name:Tony, customer_last_name:Hicks, order_id:226
# customer_first_name:Malinda, customer_last_name:Baxter, order_id:1353
# customer_first_name:Marlo, customer_last_name:Jefferson, order_id:1003
# customer_first_name:Tiana, customer_last_name:Henderson, order_id:58
# customer_first_name:Wilda, customer_last_name:Petersen, order_id:1470
# customer_first_name:Irving, customer_last_name:Pitts, order_id:527
# customer_first_name:Sheree, customer_last_name:Pena, order_id:883
# customer_first_name:Vance, customer_last_name:Taylor, order_id:1196
# customer_first_name:Terra, customer_last_name:Pickett, order_id:1262
# customer_first_name:Faustino, customer_last_name:Delacruz, order_id:254
# customer_first_name:Julienne, customer_last_name:Moody, order_id:974
# customer_first_name:Hee, customer_last_name:Greer, order_id:637
# customer_first_name:Whitney, customer_last_name:Cash, order_id:482
# customer_first_name:Clarita, customer_last_name:Curry, order_id:209
# customer_first_name:Reita, customer_last_name:Dickson, order_id:1445
# customer_first_name:Rosa, customer_last_name:Kinney, order_id:87
# customer_first_name:Buford, customer_last_name:Gilbert, order_id:1133
# customer_first_name:Homer, customer_last_name:Powers, order_id:1437
# customer_first_name:Rudolf, customer_last_name:Gilliam, order_id:912
# customer_first_name:Andreas, customer_last_name:Herman, order_id:635
# customer_first_name:Max, customer_last_name:Charles, order_id:81
# customer_first_name:Tammera, customer_last_name:Fischer, order_id:394
# customer_first_name:Joshua, customer_last_name:Robertson, order_id:3
# customer_first_name:Larraine, customer_last_name:Horn, order_id:811
# customer_first_name:Andreas, customer_last_name:Mayer, order_id:946
# customer_first_name:Lazaro, customer_last_name:Moran, order_id:67
# customer_first_name:Afton, customer_last_name:Juarez, order_id:367
# customer_first_name:Angele, customer_last_name:Schroeder, order_id:328
# customer_first_name:Ellena, customer_last_name:Clements, order_id:79
# customer_first_name:Selene, customer_last_name:Austin, order_id:687
# ...
# customer_first_name:Jaqueline, customer_last_name:Cummings, order_id:2
# customer_first_name:Yang, customer_last_name:Giles, order_id:1126
# customer_first_name:Brigid, customer_last_name:Sharp, order_id:1348
# customer_first_name:Karl, customer_last_name:Stephens, order_id:832
# customer_first_name:Elvina, customer_last_name:Gates, order_id:1299
# customer_first_name:Carlie, customer_last_name:Terrell, order_id:431
# customer_first_name:Donovan, customer_last_name:Cantrell, order_id:221
# customer_first_name:Alden, customer_last_name:Atkinson, order_id:585
# customer_first_name:Carissa, customer_last_name:Cross, order_id:45
# customer_first_name:Joy, customer_last_name:Underwood, order_id:1159
# customer_first_name:Geraldine, customer_last_name:O'donnell, order_id:809
# customer_first_name:Bronwyn, customer_last_name:Vargas, order_id:82
# customer_first_name:Abram, customer_last_name:Copeland, order_id:930
# customer_first_name:Mellisa, customer_last_name:Griffin, order_id:1040
# customer_first_name:Qiana, customer_last_name:Jackson, order_id:1208
# customer_first_name:Magali, customer_last_name:Dixon, order_id:276
# customer_first_name:Zulema, customer_last_name:Clemons, order_id:541
# customer_first_name:Carina, customer_last_name:Lynch, order_id:1037
# customer_first_name:Jesus, customer_last_name:Burch, order_id:862
# customer_first_name:Selene, customer_last_name:Vega, order_id:1423
# customer_first_name:Jong, customer_last_name:Guthrie, order_id:592
# customer_first_name:Lise, customer_last_name:Hebert, order_id:693
# customer_first_name:Joshua, customer_last_name:Berg, order_id:47
# customer_first_name:Georgina, customer_last_name:Gonzales, order_id:1043
# customer_first_name:Rudolph, customer_last_name:Velez, order_id:1269
# customer_first_name:Luke, customer_last_name:Kramer, order_id:100
# customer_first_name:Edgar, customer_last_name:Quinn, order_id:31
# customer_first_name:Tara, customer_last_name:Maynard, order_id:1430
# customer_first_name:Bella, customer_last_name:Perez, order_id:1404
# customer_first_name:Nathaniel, customer_last_name:Davidson, order_id:56
# customer_first_name:Chauncey, customer_last_name:Donaldson, order_id:696
# customer_first_name:Heide, customer_last_name:Reed, order_id:323
# customer_first_name:Trang, customer_last_name:Hardin, order_id:1152
# customer_first_name:Gabriela, customer_last_name:Warren, order_id:296
# customer_first_name:Dale, customer_last_name:Rasmussen, order_id:711
# customer_first_name:Tammie, customer_last_name:Cherry, order_id:196
# customer_first_name:Bethany, customer_last_name:Herring, order_id:557
# customer_first_name:Barbra, customer_last_name:Dickerson, order_id:653
# customer_first_name:Neoma, customer_last_name:Daugherty, order_id:21
# customer_first_name:Nanette, customer_last_name:Roman, order_id:815
# customer_first_name:Adriene, customer_last_name:Rollins, order_id:337
# customer_first_name:Susannah, customer_last_name:Fields, order_id:66
# customer_first_name:Dung, customer_last_name:Reid, order_id:1386
# customer_first_name:Ben, customer_last_name:Stone, order_id:109
# customer_first_name:Nubia, customer_last_name:Anderson, order_id:1379
# customer_first_name:Rosamaria, customer_last_name:Meyer, order_id:231
# customer_first_name:Todd, customer_last_name:Waters, order_id:1341
# customer_first_name:Kimbery, customer_last_name:Nieves, order_id:32
# customer_first_name:Phuong, customer_last_name:Wolf, order_id:1091
# customer_first_name:Adelaida, customer_last_name:Hancock, order_id:468
# customer_first_name:Brianne, customer_last_name:Hays, order_id:1160
# customer_first_name:Rufina, customer_last_name:Chandler, order_id:315
# customer_first_name:Devin, customer_last_name:Velazquez, order_id:140
# customer_first_name:Bonita, customer_last_name:Marshall, order_id:415
# customer_first_name:Myrl, customer_last_name:Gay, order_id:976
# customer_first_name:Earline, customer_last_name:Gordon, order_id:253
# customer_first_name:Sung, customer_last_name:Chambers, order_id:1273
# customer_first_name:Gustavo, customer_last_name:Gamble, order_id:1120
# customer_first_name:Ciera, customer_last_name:Webb, order_id:1044
# customer_first_name:Roy, customer_last_name:Chan, order_id:706
# customer_first_name:Houston, customer_last_name:Vasquez, order_id:576
# customer_first_name:Cheree, customer_last_name:Hale, order_id:1028
# customer_first_name:Odette, customer_last_name:Moses, order_id:385
# customer_first_name:Lenita, customer_last_name:Bonner, order_id:568
# customer_first_name:Shona, customer_last_name:Mcmillan, order_id:958
# customer_first_name:Piedad, customer_last_name:Irwin, order_id:1204
# customer_first_name:Loan, customer_last_name:Graham, order_id:902
# customer_first_name:Stan, customer_last_name:Saunders, order_id:1464
# customer_first_name:Jackeline, customer_last_name:Colon, order_id:26
# customer_first_name:Marlen, customer_last_name:Dawson, order_id:1038
# customer_first_name:Alexis, customer_last_name:Mack, order_id:552
# customer_first_name:Mica, customer_last_name:Barry, order_id:1035
# customer_first_name:Shanice, customer_last_name:Spears, order_id:1291
# customer_first_name:Garth, customer_last_name:Huff, order_id:369
# customer_first_name:Dione, customer_last_name:Pratt, order_id:154
# customer_first_name:Victor, customer_last_name:Pittman, order_id:984
# customer_first_name:Allie, customer_last_name:Conley, order_id:189
# customer_first_name:Shanelle, customer_last_name:Anderson, order_id:1198
# customer_first_name:Minnie, customer_last_name:Compton, order_id:1221
# customer_first_name:Shiloh, customer_last_name:Bates, order_id:761
# customer_first_name:Lakenya, customer_last_name:Oliver, order_id:1289
# customer_first_name:Sally, customer_last_name:Kinney, order_id:893
# customer_first_name:Edith, customer_last_name:Davenport, order_id:1313
# customer_first_name:Alline, customer_last_name:Beasley, order_id:400
# customer_first_name:Travis, customer_last_name:Whitley, order_id:39
# customer_first_name:Vanessa, customer_last_name:West, order_id:381
# customer_first_name:Trudy, customer_last_name:Riddle, order_id:782
# customer_first_name:Shauna, customer_last_name:Edwards, order_id:345
# customer_first_name:Clorinda, customer_last_name:Donovan, order_id:360
# customer_first_name:Raven, customer_last_name:Curtis, order_id:278
# customer_first_name:Verda, customer_last_name:Gilbert, order_id:638
# customer_first_name:Renay, customer_last_name:Atkins, order_id:1382
# customer_first_name:Tama, customer_last_name:Berg, order_id:1025
# customer_first_name:Dalia, customer_last_name:Carson, order_id:57
# customer_first_name:America, customer_last_name:Swanson, order_id:586
# customer_first_name:Cinda, customer_last_name:Rocha, order_id:351
# customer_first_name:Shea, customer_last_name:Howell, order_id:1031
# customer_first_name:Kimberli, customer_last_name:Cline, order_id:92
# customer_first_name:Emanuel, customer_last_name:Mckee, order_id:1471
# customer_first_name:Whitley, customer_last_name:Cannon, order_id:1097
# customer_first_name:Tereasa, customer_last_name:Bird, order_id:717
# customer_first_name:Dante, customer_last_name:Grimes, order_id:374
# customer_first_name:Joeann, customer_last_name:Garrison, order_id:257
# customer_first_name:Omega, customer_last_name:Johnston, order_id:525
# customer_first_name:Conrad, customer_last_name:Mueller, order_id:925
# customer_first_name:Glady, customer_last_name:Wells, order_id:1102
# customer_first_name:Tisha, customer_last_name:Petty, order_id:594
# customer_first_name:Claris, customer_last_name:Santiago, order_id:818
# customer_first_name:Obdulia, customer_last_name:Barber, order_id:894
# customer_first_name:Shantel, customer_last_name:Gregory, order_id:36
# customer_first_name:Ai, customer_last_name:Forbes, order_id:263
# customer_first_name:Ebony, customer_last_name:Cotton, order_id:967
# customer_first_name:Arla, customer_last_name:Ellis, order_id:5
# customer_first_name:Magdalena, customer_last_name:Sherman, order_id:163
# customer_first_name:Tarra, customer_last_name:Guerrero, order_id:11
# customer_first_name:Consuela, customer_last_name:Romero, order_id:1082
# customer_first_name:Cindie, customer_last_name:Franklin, order_id:93
# customer_first_name:Sharyn, customer_last_name:Brewer, order_id:1246
# customer_first_name:Karren, customer_last_name:Stevenson, order_id:1374
# customer_first_name:Divina, customer_last_name:Reeves, order_id:498
# customer_first_name:Novella, customer_last_name:Ross, order_id:839
# customer_first_name:Omega, customer_last_name:Huff, order_id:338
# customer_first_name:Ashleigh, customer_last_name:Finch, order_id:533
# customer_first_name:Corina, customer_last_name:Lynch, order_id:402
# customer_first_name:Joe, customer_last_name:Melton, order_id:757
# customer_first_name:Bernetta, customer_last_name:Summers, order_id:326
# customer_first_name:Inez, customer_last_name:Snider, order_id:219
# customer_first_name:Neida, customer_last_name:King, order_id:1172
# customer_first_name:Tona, customer_last_name:Velasquez, order_id:273
# customer_first_name:Rozanne, customer_last_name:Reyes, order_id:275
# customer_first_name:Lekisha, customer_last_name:Pope, order_id:1209
# customer_first_name:Jama, customer_last_name:Rodriquez, order_id:783
# customer_first_name:Eloisa, customer_last_name:Tucker, order_id:1147
# customer_first_name:Arie, customer_last_name:Hunter, order_id:1008
# customer_first_name:Sanora, customer_last_name:Webster, order_id:850
# customer_first_name:Kate, customer_last_name:Barber, order_id:1135
# customer_first_name:Yvone, customer_last_name:Guerrero, order_id:30
# customer_first_name:Kami, customer_last_name:Rios, order_id:457
# customer_first_name:Annett, customer_last_name:Rush, order_id:238
# customer_first_name:Carman, customer_last_name:Hardy, order_id:237
# customer_first_name:Dorothea, customer_last_name:Miranda, order_id:702
# customer_first_name:Agatha, customer_last_name:Daniels, order_id:537
# customer_first_name:Alexandria, customer_last_name:Zamora, order_id:135
# customer_first_name:Thad, customer_last_name:Gilliam, order_id:377
# customer_first_name:Inger, customer_last_name:Jennings, order_id:284
# customer_first_name:Karren, customer_last_name:Lamb, order_id:341
# customer_first_name:Noble, customer_last_name:Glover, order_id:220
# customer_first_name:Octavia, customer_last_name:Donaldson, order_id:508
# customer_first_name:Latashia, customer_last_name:Travis, order_id:232
# customer_first_name:Destiny, customer_last_name:Goodman, order_id:174
# customer_first_name:Christiana, customer_last_name:Gross, order_id:386
# customer_first_name:Nestor, customer_last_name:Haynes, order_id:788
# customer_first_name:Grisel, customer_last_name:Maynard, order_id:1274
# customer_first_name:Shenna, customer_last_name:Espinoza, order_id:126
# customer_first_name:Trena, customer_last_name:Rogers, order_id:193
# customer_first_name:Lucile, customer_last_name:Manning, order_id:1248
# customer_first_name:Veronique, customer_last_name:Fulton, order_id:223
# customer_first_name:Starr, customer_last_name:Schneider, order_id:115
# customer_first_name:Rona, customer_last_name:Rojas, order_id:1026
# customer_first_name:Pandora, customer_last_name:Estes, order_id:443
# customer_first_name:Renna, customer_last_name:Williams, order_id:1083
# customer_first_name:Lanora, customer_last_name:Robbins, order_id:212
# customer_first_name:Juliane, customer_last_name:Dillard, order_id:518
# customer_first_name:Carlena, customer_last_name:Salinas, order_id:302
# customer_first_name:Kimberley, customer_last_name:Reynolds, order_id:248
# customer_first_name:Johana, customer_last_name:Jacobson, order_id:416
# customer_first_name:Enoch, customer_last_name:Rosario, order_id:507
# customer_first_name:Dorine, customer_last_name:Thornton, order_id:1148
# customer_first_name:Eliz, customer_last_name:Lynch, order_id:406
# customer_first_name:Mercedez, customer_last_name:Brooks, order_id:504
# customer_first_name:Wynona, customer_last_name:Douglas, order_id:1095
# customer_first_name:Desire, customer_last_name:Mcgowan, order_id:1398
# customer_first_name:Elmo, customer_last_name:Sweeney, order_id:1307
# customer_first_name:Kenton, customer_last_name:Hughes, order_id:773
# customer_first_name:Cesar, customer_last_name:Wilkins, order_id:72
# customer_first_name:Phylicia, customer_last_name:Stout, order_id:353
# customer_first_name:Nanette, customer_last_name:Harris, order_id:1270
# customer_first_name:Ulrike, customer_last_name:Chan, order_id:1004
# customer_first_name:Genoveva, customer_last_name:Lloyd, order_id:960
# customer_first_name:Sheryl, customer_last_name:Chase, order_id:659
# customer_first_name:Trista, customer_last_name:Lambert, order_id:1100
# customer_first_name:Vivian, customer_last_name:Deleon, order_id:1342
# customer_first_name:Genny, customer_last_name:Fields, order_id:1103
# customer_first_name:Eliseo, customer_last_name:Knight, order_id:838
# customer_first_name:Delma, customer_last_name:Bailey, order_id:886
# customer_first_name:Dewayne, customer_last_name:Herring, order_id:423
# customer_first_name:Nevada, customer_last_name:Hood, order_id:622
# customer_first_name:Angelika, customer_last_name:Perry, order_id:722
# customer_first_name:Shayla, customer_last_name:Hart, order_id:311
# customer_first_name:Willetta, customer_last_name:Murphy, order_id:1293
# customer_first_name:Sandee, customer_last_name:Alvarado, order_id:857
# customer_first_name:Mila, customer_last_name:Moody, order_id:968
# customer_first_name:Loyce, customer_last_name:Conway, order_id:630
# customer_first_name:Thanh, customer_last_name:Figueroa, order_id:560
# customer_first_name:Farrah, customer_last_name:Orr, order_id:534
# customer_first_name:Hugh, customer_last_name:Craft, order_id:939
# customer_first_name:Eleanor, customer_last_name:Mendez, order_id:1263
# customer_first_name:Lamar, customer_last_name:Bush, order_id:1304
# customer_first_name:Lurlene, customer_last_name:Finch, order_id:866
# customer_first_name:Shanda, customer_last_name:Stevenson, order_id:1457
# customer_first_name:Adrien, customer_last_name:Hunter, order_id:1193
# customer_first_name:Ophelia, customer_last_name:Decker, order_id:69
# customer_first_name:Sonja, customer_last_name:Walls, order_id:1144
# customer_first_name:Harold, customer_last_name:O'connor, order_id:993
# customer_first_name:Miranda, customer_last_name:Kennedy, order_id:870
# customer_first_name:Jasper, customer_last_name:Castro, order_id:1016
# customer_first_name:Penni, customer_last_name:Best, order_id:1002
# customer_first_name:Lurlene, customer_last_name:Cotton, order_id:1447
# customer_first_name:Kelsey, customer_last_name:Noble, order_id:215
# customer_first_name:Edris, customer_last_name:Barrett, order_id:1169
# customer_first_name:Tempie, customer_last_name:Jacobson, order_id:1182
# customer_first_name:Dollie, customer_last_name:Cervantes, order_id:982
# customer_first_name:Lashunda, customer_last_name:Cole, order_id:1107
# customer_first_name:Justina, customer_last_name:Jenkins, order_id:297
# customer_first_name:Londa, customer_last_name:Gould, order_id:971
# customer_first_name:Mikel, customer_last_name:Wilkerson, order_id:1090
# customer_first_name:Carola, customer_last_name:Johns, order_id:320
# customer_first_name:Lorrie, customer_last_name:Justice, order_id:540
# customer_first_name:Tayna, customer_last_name:Wade, order_id:567
# customer_first_name:Mark, customer_last_name:Benton, order_id:114
# customer_first_name:Zona, customer_last_name:Cameron, order_id:963
# customer_first_name:Nicola, customer_last_name:Knight, order_id:1352
# customer_first_name:Elana, customer_last_name:Miles, order_id:43
# customer_first_name:Merrie, customer_last_name:Fowler, order_id:234
# customer_first_name:Macie, customer_last_name:Ayers, order_id:844
# customer_first_name:Son, customer_last_name:Warner, order_id:397
# customer_first_name:Lee, customer_last_name:Dunn, order_id:927
# customer_first_name:Florrie, customer_last_name:Little, order_id:1053
# customer_first_name:Ernest, customer_last_name:Rollins, order_id:466
# customer_first_name:Jamaal, customer_last_name:Morrison, order_id:1366
# customer_first_name:Cassie, customer_last_name:Cline, order_id:1036
# customer_first_name:Lezlie, customer_last_name:Lamb, order_id:558
# customer_first_name:Ivette, customer_last_name:Estes, order_id:616
# customer_first_name:Ester, customer_last_name:Acevedo, order_id:1424

# %% [markdown]
# #### Task 4.2: Retrieve Customer Names with Order IDs and Total Orders

# %%
query="""select customers.first_name,customers.last_name,count(orders.order_id) as TotalOrders
from customers
join orders
on customers.customer_id=orders.customer_id
group by customers.first_name,customers.last_name
"""
cursor.execute(query)
rows=cursor.fetchall()
for row in rows:
    print(f"customer_first_name:{row[0]}, customer_last_name:{row[1]}, totalorders:{row[2]}")
# Out:
# customer_first_name:Aaron, customer_last_name:Knapp, totalorders:1
# customer_first_name:Abbey, customer_last_name:Pugh, totalorders:1
# customer_first_name:Abby, customer_last_name:Gamble, totalorders:2
# customer_first_name:Abram, customer_last_name:Copeland, totalorders:1
# customer_first_name:Adam, customer_last_name:Henderson, totalorders:1
# customer_first_name:Adam, customer_last_name:Thornton, totalorders:1
# customer_first_name:Addie, customer_last_name:Hahn, totalorders:1
# customer_first_name:Adelaida, customer_last_name:Hancock, totalorders:1
# customer_first_name:Adelle, customer_last_name:Larsen, totalorders:2
# customer_first_name:Adena, customer_last_name:Blake, totalorders:1
# customer_first_name:Adrien, customer_last_name:Hunter, totalorders:1
# customer_first_name:Adriene, customer_last_name:Rivera, totalorders:1
# customer_first_name:Adriene, customer_last_name:Rollins, totalorders:1
# customer_first_name:Afton, customer_last_name:Juarez, totalorders:1
# customer_first_name:Agatha, customer_last_name:Daniels, totalorders:1
# customer_first_name:Agatha, customer_last_name:Melton, totalorders:1
# customer_first_name:Agnes, customer_last_name:Sims, totalorders:1
# customer_first_name:Agustina, customer_last_name:Lawrence, totalorders:1
# customer_first_name:Ai, customer_last_name:Forbes, totalorders:1
# customer_first_name:Aida, customer_last_name:Koch, totalorders:1
# customer_first_name:Aide, customer_last_name:Franco, totalorders:1
# customer_first_name:Aileen, customer_last_name:Marquez, totalorders:1
# customer_first_name:Aimee, customer_last_name:Merritt, totalorders:1
# customer_first_name:Aisha, customer_last_name:Woods, totalorders:1
# customer_first_name:Alane, customer_last_name:Kennedy, totalorders:1
# customer_first_name:Alane, customer_last_name:Mccarty, totalorders:1
# customer_first_name:Alane, customer_last_name:Munoz, totalorders:1
# customer_first_name:Alanna, customer_last_name:Barry, totalorders:1
# customer_first_name:Alden, customer_last_name:Atkinson, totalorders:1
# customer_first_name:Alec, customer_last_name:Peck, totalorders:1
# customer_first_name:Alejandrina, customer_last_name:Hodges, totalorders:1
# customer_first_name:Alejandro, customer_last_name:Haney, totalorders:1
# customer_first_name:Alejandro, customer_last_name:Norman, totalorders:1
# customer_first_name:Alesia, customer_last_name:Horne, totalorders:1
# customer_first_name:Aleta, customer_last_name:Mack, totalorders:1
# customer_first_name:Aleta, customer_last_name:Shepard, totalorders:3
# customer_first_name:Aleta, customer_last_name:Stone, totalorders:1
# customer_first_name:Alexandria, customer_last_name:Zamora, totalorders:1
# customer_first_name:Alexis, customer_last_name:Mack, totalorders:1
# customer_first_name:Alfredo, customer_last_name:Dodson, totalorders:1
# customer_first_name:Alica, customer_last_name:Hunter, totalorders:2
# customer_first_name:Alina, customer_last_name:Mcleod, totalorders:1
# customer_first_name:Alishia, customer_last_name:Elliott, totalorders:1
# customer_first_name:Alisia, customer_last_name:Albert, totalorders:1
# customer_first_name:Alissa, customer_last_name:Craft, totalorders:1
# customer_first_name:Alissa, customer_last_name:Hood, totalorders:1
# customer_first_name:Alita, customer_last_name:Salinas, totalorders:1
# customer_first_name:Allie, customer_last_name:Conley, totalorders:1
# customer_first_name:Alline, customer_last_name:Beasley, totalorders:1
# customer_first_name:Allison, customer_last_name:Nolan, totalorders:1
# customer_first_name:Alma, customer_last_name:Peck, totalorders:1
# customer_first_name:Almeta, customer_last_name:Benjamin, totalorders:1
# customer_first_name:Alpha, customer_last_name:King, totalorders:1
# customer_first_name:Alyse, customer_last_name:Jacobson, totalorders:1
# customer_first_name:Alysha, customer_last_name:Powers, totalorders:1
# customer_first_name:Alysia, customer_last_name:Nicholson, totalorders:1
# customer_first_name:America, customer_last_name:Swanson, totalorders:1
# customer_first_name:Ami, customer_last_name:Mcmahon, totalorders:1
# customer_first_name:Amina, customer_last_name:Salazar, totalorders:1
# customer_first_name:Amparo, customer_last_name:Burks, totalorders:1
# customer_first_name:Ana, customer_last_name:Palmer, totalorders:1
# customer_first_name:Anderson, customer_last_name:Martin, totalorders:1
# customer_first_name:Andreas, customer_last_name:Herman, totalorders:1
# customer_first_name:Andreas, customer_last_name:Mayer, totalorders:1
# customer_first_name:Andria, customer_last_name:Rivers, totalorders:1
# customer_first_name:Andy, customer_last_name:O'neill, totalorders:1
# customer_first_name:Angele, customer_last_name:Castro, totalorders:1
# customer_first_name:Angele, customer_last_name:Schroeder, totalorders:1
# customer_first_name:Angelika, customer_last_name:Perry, totalorders:1
# customer_first_name:Angelina, customer_last_name:Lloyd, totalorders:1
# customer_first_name:Angelique, customer_last_name:Merrill, totalorders:1
# customer_first_name:Angella, customer_last_name:Bridges, totalorders:1
# customer_first_name:Angie, customer_last_name:Powers, totalorders:1
# customer_first_name:Anisha, customer_last_name:Lang, totalorders:1
# customer_first_name:Ann, customer_last_name:Heath, totalorders:1
# customer_first_name:Annabelle, customer_last_name:Hebert, totalorders:1
# customer_first_name:Annett, customer_last_name:Garrett, totalorders:1
# customer_first_name:Annett, customer_last_name:Rush, totalorders:1
# customer_first_name:Annis, customer_last_name:Sanchez, totalorders:1
# customer_first_name:Anton, customer_last_name:Barton, totalorders:1
# customer_first_name:Antonetta, customer_last_name:Rocha, totalorders:1
# customer_first_name:Antony, customer_last_name:Atkinson, totalorders:1
# customer_first_name:Anya, customer_last_name:Contreras, totalorders:1
# customer_first_name:Ara, customer_last_name:Vazquez, totalorders:1
# customer_first_name:Araceli, customer_last_name:Golden, totalorders:3
# customer_first_name:Arcelia, customer_last_name:Vinson, totalorders:1
# customer_first_name:Ardelia, customer_last_name:Cooley, totalorders:1
# customer_first_name:Arie, customer_last_name:Hunter, totalorders:1
# customer_first_name:Arielle, customer_last_name:Levine, totalorders:1
# customer_first_name:Arla, customer_last_name:Ellis, totalorders:1
# customer_first_name:Arlena, customer_last_name:Buckner, totalorders:1
# customer_first_name:Arline, customer_last_name:Lawson, totalorders:1
# customer_first_name:Armand, customer_last_name:Whitehead, totalorders:2
# customer_first_name:Armando, customer_last_name:Black, totalorders:1
# customer_first_name:Arminda, customer_last_name:Weber, totalorders:1
# customer_first_name:Arnita, customer_last_name:Thomas, totalorders:1
# customer_first_name:Aron, customer_last_name:Wiggins, totalorders:1
# customer_first_name:Arvilla, customer_last_name:Osborn, totalorders:2
# customer_first_name:Arvilla, customer_last_name:Weiss, totalorders:1
# customer_first_name:Ashanti, customer_last_name:Hammond, totalorders:1
# customer_first_name:Ashanti, customer_last_name:Parks, totalorders:2
# customer_first_name:Ashely, customer_last_name:Holmes, totalorders:1
# customer_first_name:Ashlee, customer_last_name:Pena, totalorders:1
# customer_first_name:Ashleigh, customer_last_name:Finch, totalorders:1
# customer_first_name:Ashleigh, customer_last_name:Frank, totalorders:1
# customer_first_name:Ashlie, customer_last_name:Parrish, totalorders:1
# customer_first_name:Ashton, customer_last_name:Lott, totalorders:1
# customer_first_name:Aubrey, customer_last_name:Durham, totalorders:1
# customer_first_name:Augustina, customer_last_name:Joyner, totalorders:1
# customer_first_name:Augustus, customer_last_name:Schmidt, totalorders:1
# customer_first_name:Augustus, customer_last_name:Steele, totalorders:1
# customer_first_name:Ayana, customer_last_name:Keith, totalorders:1
# customer_first_name:Ayanna, customer_last_name:Cherry, totalorders:1
# customer_first_name:Ayanna, customer_last_name:Rhodes, totalorders:1
# customer_first_name:Babara, customer_last_name:Ochoa, totalorders:1
# customer_first_name:Bao, customer_last_name:Wade, totalorders:1
# customer_first_name:Barbera, customer_last_name:Riggs, totalorders:1
# customer_first_name:Barbra, customer_last_name:Dickerson, totalorders:1
# customer_first_name:Barrett, customer_last_name:Sanders, totalorders:1
# customer_first_name:Barry, customer_last_name:Albert, totalorders:1
# customer_first_name:Barry, customer_last_name:Buckner, totalorders:1
# customer_first_name:Bart, customer_last_name:Hess, totalorders:1
# customer_first_name:Barton, customer_last_name:Cox, totalorders:1
# customer_first_name:Barton, customer_last_name:Crosby, totalorders:1
# customer_first_name:Basil, customer_last_name:Ballard, totalorders:1
# customer_first_name:Basilia, customer_last_name:Thornton, totalorders:1
# customer_first_name:Bea, customer_last_name:Kane, totalorders:1
# customer_first_name:Beatris, customer_last_name:Joyner, totalorders:1
# customer_first_name:Bee, customer_last_name:Baker, totalorders:1
# customer_first_name:Bella, customer_last_name:Perez, totalorders:1
# customer_first_name:Ben, customer_last_name:Stone, totalorders:1
# customer_first_name:Benito, customer_last_name:Hendrix, totalorders:1
# customer_first_name:Bennett, customer_last_name:Armstrong, totalorders:2
# customer_first_name:Benny, customer_last_name:Bender, totalorders:1
# customer_first_name:Berna, customer_last_name:Moore, totalorders:1
# customer_first_name:Bernardina, customer_last_name:Cooper, totalorders:1
# customer_first_name:Berneice, customer_last_name:Pollard, totalorders:1
# customer_first_name:Bernetta, customer_last_name:Marquez, totalorders:1
# customer_first_name:Bernetta, customer_last_name:Summers, totalorders:1
# customer_first_name:Bernita, customer_last_name:Mcdaniel, totalorders:2
# customer_first_name:Beryl, customer_last_name:Bennett, totalorders:1
# customer_first_name:Bess, customer_last_name:Mcbride, totalorders:1
# customer_first_name:Bethany, customer_last_name:Herring, totalorders:1
# customer_first_name:Bettie, customer_last_name:Glover, totalorders:1
# customer_first_name:Bettie, customer_last_name:Pierce, totalorders:1
# customer_first_name:Bettyann, customer_last_name:Acosta, totalorders:1
# customer_first_name:Bettye, customer_last_name:Espinoza, totalorders:1
# customer_first_name:Bev, customer_last_name:Chang, totalorders:1
# customer_first_name:Birdie, customer_last_name:Kramer, totalorders:1
# customer_first_name:Blanca, customer_last_name:Hooper, totalorders:1
# customer_first_name:Bobbi, customer_last_name:Banks, totalorders:1
# customer_first_name:Bobbie, customer_last_name:Foster, totalorders:3
# customer_first_name:Bong, customer_last_name:Hebert, totalorders:2
# customer_first_name:Bonita, customer_last_name:Marshall, totalorders:1
# customer_first_name:Boyce, customer_last_name:Burks, totalorders:1
# customer_first_name:Boyd, customer_last_name:Irwin, totalorders:1
# customer_first_name:Brain, customer_last_name:Skinner, totalorders:1
# customer_first_name:Brenda, customer_last_name:Tate, totalorders:1
# customer_first_name:Brent, customer_last_name:Calderon, totalorders:1
# customer_first_name:Brenton, customer_last_name:Whitaker, totalorders:1
# customer_first_name:Brianna, customer_last_name:Moss, totalorders:1
# customer_first_name:Brianne, customer_last_name:Hays, totalorders:1
# customer_first_name:Bridgette, customer_last_name:Guerra, totalorders:3
# customer_first_name:Brigid, customer_last_name:Sharp, totalorders:1
# customer_first_name:Brigida, customer_last_name:Larson, totalorders:1
# customer_first_name:Britteny, customer_last_name:Schroeder, totalorders:1
# customer_first_name:Brittney, customer_last_name:Rojas, totalorders:1
# customer_first_name:Brittney, customer_last_name:Woodward, totalorders:2
# customer_first_name:Brittni, customer_last_name:Green, totalorders:1
# customer_first_name:Bronwyn, customer_last_name:Vargas, totalorders:1
# customer_first_name:Bryce, customer_last_name:Monroe, totalorders:1
# customer_first_name:Buford, customer_last_name:Bridges, totalorders:1
# customer_first_name:Buford, customer_last_name:Gilbert, totalorders:1
# customer_first_name:Burma, customer_last_name:Summers, totalorders:1
# customer_first_name:Calandra, customer_last_name:Stanton, totalorders:1
# customer_first_name:Caleb, customer_last_name:England, totalorders:1
# customer_first_name:Cameron, customer_last_name:Carroll, totalorders:1
# customer_first_name:Cami, customer_last_name:Williamson, totalorders:1
# customer_first_name:Camila, customer_last_name:Carroll, totalorders:1
# customer_first_name:Camille, customer_last_name:Harvey, totalorders:1
# customer_first_name:Candelaria, customer_last_name:Coffey, totalorders:1
# customer_first_name:Candis, customer_last_name:Harding, totalorders:1
# customer_first_name:Caren, customer_last_name:Stephens, totalorders:3
# customer_first_name:Caridad, customer_last_name:Compton, totalorders:1
# customer_first_name:Carie, customer_last_name:Kidd, totalorders:1
# customer_first_name:Carina, customer_last_name:Lynch, totalorders:1
# customer_first_name:Carisa, customer_last_name:Carpenter, totalorders:1
# customer_first_name:Carissa, customer_last_name:Cross, totalorders:1
# customer_first_name:Carissa, customer_last_name:Foreman, totalorders:1
# customer_first_name:Carita, customer_last_name:Salinas, totalorders:1
# customer_first_name:Carlena, customer_last_name:Salinas, totalorders:1
# customer_first_name:Carley, customer_last_name:Reynolds, totalorders:2
# customer_first_name:Carlie, customer_last_name:Terrell, totalorders:1
# customer_first_name:Carline, customer_last_name:Collier, totalorders:2
# customer_first_name:Carman, customer_last_name:Hardy, totalorders:1
# customer_first_name:Carmela, customer_last_name:Hays, totalorders:1
# customer_first_name:Carmelina, customer_last_name:Sellers, totalorders:1
# customer_first_name:Carmina, customer_last_name:Emerson, totalorders:1
# customer_first_name:Carola, customer_last_name:Johns, totalorders:1
# customer_first_name:Carola, customer_last_name:Mcpherson, totalorders:1
# customer_first_name:Carola, customer_last_name:Rodriquez, totalorders:2
# customer_first_name:Carolann, customer_last_name:Russell, totalorders:1
# customer_first_name:Caroline, customer_last_name:Jenkins, totalorders:1
# customer_first_name:Caroll, customer_last_name:Hays, totalorders:2
# customer_first_name:Carolyne, customer_last_name:Conley, totalorders:1
# customer_first_name:Carroll, customer_last_name:Kelly, totalorders:1
# customer_first_name:Carson, customer_last_name:Macias, totalorders:1
# customer_first_name:Carter, customer_last_name:Bentley, totalorders:1
# customer_first_name:Carter, customer_last_name:Booth, totalorders:1
# customer_first_name:Casey, customer_last_name:Gill, totalorders:1
# customer_first_name:Casimira, customer_last_name:Chapman, totalorders:1
# customer_first_name:Cassandra, customer_last_name:Nichols, totalorders:1
# customer_first_name:Cassidy, customer_last_name:Clark, totalorders:1
# customer_first_name:Cassie, customer_last_name:Cline, totalorders:1
# customer_first_name:Cassondra, customer_last_name:Pruitt, totalorders:1
# customer_first_name:Catarina, customer_last_name:Mendez, totalorders:1
# customer_first_name:Catherine, customer_last_name:Miles, totalorders:1
# customer_first_name:Cathey, customer_last_name:Lamb, totalorders:1
# customer_first_name:Catrice, customer_last_name:Hicks, totalorders:1
# customer_first_name:Cayla, customer_last_name:Johnson, totalorders:1
# customer_first_name:Cecelia, customer_last_name:Gill, totalorders:1
# customer_first_name:Cecil, customer_last_name:Hopper, totalorders:1
# customer_first_name:Cecilia, customer_last_name:Camacho, totalorders:1
# customer_first_name:Celestine, customer_last_name:Jacobs, totalorders:1
# customer_first_name:Celestine, customer_last_name:Kent, totalorders:1
# customer_first_name:Cesar, customer_last_name:Jackson, totalorders:2
# customer_first_name:Cesar, customer_last_name:Wilkins, totalorders:1
# customer_first_name:Chanel, customer_last_name:May, totalorders:1
# customer_first_name:Chantay, customer_last_name:Maynard, totalorders:1
# customer_first_name:Chantell, customer_last_name:Bridges, totalorders:1
# customer_first_name:Charise, customer_last_name:Burt, totalorders:1
# customer_first_name:Charleen, customer_last_name:Hurst, totalorders:1
# customer_first_name:Charleen, customer_last_name:Joyner, totalorders:1
# customer_first_name:Charlene, customer_last_name:Norris, totalorders:1
# customer_first_name:Charlesetta, customer_last_name:Soto, totalorders:1
# customer_first_name:Charlsie, customer_last_name:Carson, totalorders:1
# customer_first_name:Charlyn, customer_last_name:Cantrell, totalorders:1
# customer_first_name:Charmain, customer_last_name:Webster, totalorders:1
# customer_first_name:Charolette, customer_last_name:Rice, totalorders:3
# customer_first_name:Chasidy, customer_last_name:Tran, totalorders:1
# customer_first_name:Chasidy, customer_last_name:Webster, totalorders:1
# customer_first_name:Chauncey, customer_last_name:Donaldson, totalorders:1
# customer_first_name:Chelsey, customer_last_name:Boyd, totalorders:1
# customer_first_name:Chelsey, customer_last_name:Hardin, totalorders:1
# customer_first_name:Cher, customer_last_name:Alston, totalorders:1
# customer_first_name:Chere, customer_last_name:Alston, totalorders:1
# customer_first_name:Chere, customer_last_name:Hardin, totalorders:1
# customer_first_name:Chere, customer_last_name:Mcfadden, totalorders:1
# customer_first_name:Cheree, customer_last_name:Hale, totalorders:1
# customer_first_name:Cherelle, customer_last_name:Key, totalorders:1
# customer_first_name:Cheryll, customer_last_name:Snyder, totalorders:1
# customer_first_name:Chi, customer_last_name:Goff, totalorders:2
# customer_first_name:Chloe, customer_last_name:Patel, totalorders:1
# customer_first_name:Christel, customer_last_name:Barber, totalorders:1
# customer_first_name:Christel, customer_last_name:Cardenas, totalorders:1
# customer_first_name:Christia, customer_last_name:Carson, totalorders:1
# customer_first_name:Christia, customer_last_name:Wilkins, totalorders:1
# customer_first_name:Christiana, customer_last_name:Gross, totalorders:1
# customer_first_name:Christiane, customer_last_name:Bradford, totalorders:1
# customer_first_name:Christoper, customer_last_name:Gould, totalorders:1
# customer_first_name:Christoper, customer_last_name:Mccall, totalorders:1
# customer_first_name:Christopher, customer_last_name:Richardson, totalorders:1
# customer_first_name:Cicely, customer_last_name:Deleon, totalorders:1
# customer_first_name:Ciera, customer_last_name:Koch, totalorders:1
# customer_first_name:Ciera, customer_last_name:Webb, totalorders:1
# customer_first_name:Cinda, customer_last_name:Rocha, totalorders:1
# customer_first_name:Cindi, customer_last_name:Ellis, totalorders:1
# customer_first_name:Cindi, customer_last_name:Larson, totalorders:1
# customer_first_name:Cindie, customer_last_name:Franklin, totalorders:1
# customer_first_name:Cinthia, customer_last_name:Poole, totalorders:1
# customer_first_name:Cira, customer_last_name:Downs, totalorders:1
# customer_first_name:Clare, customer_last_name:Neal, totalorders:1
# customer_first_name:Claris, customer_last_name:Santiago, totalorders:1
# customer_first_name:Clarita, customer_last_name:Curry, totalorders:1
# customer_first_name:Claudio, customer_last_name:Wise, totalorders:1
# customer_first_name:Clelia, customer_last_name:Workman, totalorders:1
# customer_first_name:Clementina, customer_last_name:Sargent, totalorders:1
# customer_first_name:Clementine, customer_last_name:Mooney, totalorders:1
# customer_first_name:Cleopatra, customer_last_name:Tate, totalorders:1
# customer_first_name:Cleotilde, customer_last_name:Booth, totalorders:3
# customer_first_name:Clorinda, customer_last_name:Donovan, totalorders:1
# customer_first_name:Coleen, customer_last_name:Navarro, totalorders:1
# customer_first_name:Coleman, customer_last_name:Boyd, totalorders:1
# customer_first_name:Collen, customer_last_name:Dennis, totalorders:1
# customer_first_name:Collen, customer_last_name:Hayes, totalorders:1
# customer_first_name:Collene, customer_last_name:Knox, totalorders:1
# customer_first_name:Collene, customer_last_name:Roman, totalorders:1
# customer_first_name:Collin, customer_last_name:Webster, totalorders:1
# customer_first_name:Conception, customer_last_name:Slater, totalorders:1
# customer_first_name:Conchita, customer_last_name:Boone, totalorders:1
# customer_first_name:Conrad, customer_last_name:Mueller, totalorders:1
# customer_first_name:Consuela, customer_last_name:Collier, totalorders:1
# customer_first_name:Consuela, customer_last_name:Romero, totalorders:1
# customer_first_name:Corene, customer_last_name:Swanson, totalorders:1
# customer_first_name:Corene, customer_last_name:Wall, totalorders:3
# customer_first_name:Cori, customer_last_name:Schwartz, totalorders:1
# customer_first_name:Corina, customer_last_name:Lynch, totalorders:1
# customer_first_name:Corine, customer_last_name:Stuart, totalorders:1
# customer_first_name:Corinna, customer_last_name:Adams, totalorders:1
# customer_first_name:Corrina, customer_last_name:Sawyer, totalorders:2
# customer_first_name:Corrinne, customer_last_name:Garrison, totalorders:1
# customer_first_name:Courtney, customer_last_name:Wyatt, totalorders:1
# customer_first_name:Cris, customer_last_name:Dunn, totalorders:1
# customer_first_name:Cristobal, customer_last_name:Hutchinson, totalorders:1
# customer_first_name:Crysta, customer_last_name:Velez, totalorders:1
# customer_first_name:Crystle, customer_last_name:Gilliam, totalorders:1
# customer_first_name:Cyndi, customer_last_name:Bush, totalorders:1
# customer_first_name:Cyndi, customer_last_name:Dyer, totalorders:1
# customer_first_name:Dacia, customer_last_name:William, totalorders:2
# customer_first_name:Dagny, customer_last_name:Owen, totalorders:1
# customer_first_name:Daina, customer_last_name:Sampson, totalorders:1
# customer_first_name:Daisy, customer_last_name:Ward, totalorders:1
# customer_first_name:Dale, customer_last_name:Rasmussen, totalorders:1
# customer_first_name:Dalia, customer_last_name:Carson, totalorders:1
# customer_first_name:Damian, customer_last_name:Dawson, totalorders:1
# customer_first_name:Damian, customer_last_name:Mills, totalorders:1
# customer_first_name:Damien, customer_last_name:Dorsey, totalorders:2
# customer_first_name:Dane, customer_last_name:Mcdaniel, totalorders:1
# customer_first_name:Danielle, customer_last_name:Bond, totalorders:1
# customer_first_name:Danille, customer_last_name:Mcfarland, totalorders:1
# customer_first_name:Danilo, customer_last_name:Holmes, totalorders:1
# customer_first_name:Dann, customer_last_name:Huff, totalorders:1
# customer_first_name:Dannette, customer_last_name:Guerrero, totalorders:1
# customer_first_name:Danny, customer_last_name:Kim, totalorders:1
# customer_first_name:Dante, customer_last_name:Grimes, totalorders:1
# customer_first_name:Danyell, customer_last_name:Dickerson, totalorders:1
# customer_first_name:Daphine, customer_last_name:Willis, totalorders:1
# customer_first_name:Darcel, customer_last_name:Harmon, totalorders:1
# customer_first_name:Darcie, customer_last_name:Morgan, totalorders:1
# customer_first_name:Darren, customer_last_name:Witt, totalorders:1
# customer_first_name:Daryl, customer_last_name:Spence, totalorders:3
# customer_first_name:Davis, customer_last_name:Long, totalorders:1
# customer_first_name:Deandrea, customer_last_name:Cox, totalorders:1
# customer_first_name:Deandrea, customer_last_name:Vega, totalorders:1
# customer_first_name:Deane, customer_last_name:Sears, totalorders:1
# customer_first_name:Deangelo, customer_last_name:Cooley, totalorders:1
# customer_first_name:Deanne, customer_last_name:Parsons, totalorders:1
# customer_first_name:Debbra, customer_last_name:Jacobson, totalorders:1
# customer_first_name:Debra, customer_last_name:Burks, totalorders:3
# customer_first_name:Deirdre, customer_last_name:Ryan, totalorders:1
# customer_first_name:Deja, customer_last_name:Chaney, totalorders:1
# customer_first_name:Delaine, customer_last_name:Estes, totalorders:1
# customer_first_name:Delana, customer_last_name:Scott, totalorders:1
# customer_first_name:Delana, customer_last_name:Wagner, totalorders:1
# customer_first_name:Delbert, customer_last_name:Wilkins, totalorders:1
# customer_first_name:Delfina, customer_last_name:Gilliam, totalorders:1
# customer_first_name:Delila, customer_last_name:Hamilton, totalorders:1
# customer_first_name:Delma, customer_last_name:Bailey, totalorders:1
# customer_first_name:Delmar, customer_last_name:Wise, totalorders:1
# customer_first_name:Deloris, customer_last_name:Burke, totalorders:3
# customer_first_name:Deloris, customer_last_name:Larson, totalorders:1
# customer_first_name:Demarcus, customer_last_name:Reese, totalorders:1
# customer_first_name:Denis, customer_last_name:Logan, totalorders:2
# customer_first_name:Derrick, customer_last_name:Marks, totalorders:1
# customer_first_name:Deshawn, customer_last_name:Mendoza, totalorders:3
# customer_first_name:Desire, customer_last_name:Mcgowan, totalorders:1
# customer_first_name:Desiree, customer_last_name:Branch, totalorders:1
# customer_first_name:Desmond, customer_last_name:Rose, totalorders:1
# customer_first_name:Destiny, customer_last_name:Goodman, totalorders:1
# customer_first_name:Devin, customer_last_name:Shaffer, totalorders:1
# customer_first_name:Devin, customer_last_name:Velazquez, totalorders:1
# customer_first_name:Dewayne, customer_last_name:Herring, totalorders:1
# customer_first_name:Dexter, customer_last_name:Roberts, totalorders:1
# customer_first_name:Diana, customer_last_name:Cobb, totalorders:1
# customer_first_name:Diana, customer_last_name:Guerra, totalorders:2
# customer_first_name:Diana, customer_last_name:Reyes, totalorders:1
# customer_first_name:Diane, customer_last_name:Jones, totalorders:1
# customer_first_name:Dione, customer_last_name:Pratt, totalorders:1
# customer_first_name:Dionne, customer_last_name:Norris, totalorders:1
# customer_first_name:Divina, customer_last_name:Madden, totalorders:1
# customer_first_name:Divina, customer_last_name:Reeves, totalorders:1
# customer_first_name:Dollie, customer_last_name:Cervantes, totalorders:1
# customer_first_name:Domingo, customer_last_name:Casey, totalorders:1
# customer_first_name:Donette, customer_last_name:Mccarthy, totalorders:1
# customer_first_name:Donnetta, customer_last_name:Henson, totalorders:1
# customer_first_name:Donovan, customer_last_name:Cantrell, totalorders:1
# customer_first_name:Doreatha, customer_last_name:Ford, totalorders:1
# customer_first_name:Dori, customer_last_name:Alvarez, totalorders:1
# customer_first_name:Dorine, customer_last_name:Roberson, totalorders:2
# customer_first_name:Dorine, customer_last_name:Thornton, totalorders:1
# customer_first_name:Doris, customer_last_name:Kaufman, totalorders:1
# customer_first_name:Dorothea, customer_last_name:Chang, totalorders:1
# customer_first_name:Dorothea, customer_last_name:Miranda, totalorders:1
# customer_first_name:Dortha, customer_last_name:Jarvis, totalorders:1
# customer_first_name:Dorthea, customer_last_name:Walker, totalorders:1
# customer_first_name:Dorthey, customer_last_name:Jackson, totalorders:2
# customer_first_name:Dottie, customer_last_name:Roberts, totalorders:1
# customer_first_name:Douglas, customer_last_name:Richards, totalorders:1
# customer_first_name:Douglass, customer_last_name:Blankenship, totalorders:1
# customer_first_name:Douglass, customer_last_name:Little, totalorders:1
# customer_first_name:Drucilla, customer_last_name:Gilliam, totalorders:1
# customer_first_name:Dung, customer_last_name:King, totalorders:1
# customer_first_name:Dung, customer_last_name:Reid, totalorders:1
# customer_first_name:Dwain, customer_last_name:Carlson, totalorders:1
# customer_first_name:Earl, customer_last_name:Stanley, totalorders:1
# customer_first_name:Earlean, customer_last_name:Pena, totalorders:1
# customer_first_name:Earline, customer_last_name:Ballard, totalorders:1
# customer_first_name:Earline, customer_last_name:Gordon, totalorders:1
# customer_first_name:Ebony, customer_last_name:Cotton, totalorders:1
# customer_first_name:Edda, customer_last_name:Young, totalorders:1
# customer_first_name:Edgar, customer_last_name:Horn, totalorders:1
# customer_first_name:Edgar, customer_last_name:Quinn, totalorders:1
# customer_first_name:Edith, customer_last_name:Davenport, totalorders:1
# customer_first_name:Edmund, customer_last_name:Gaines, totalorders:1
# customer_first_name:Edra, customer_last_name:Fitzgerald, totalorders:1
# customer_first_name:Edris, customer_last_name:Barrett, totalorders:1
# customer_first_name:Edythe, customer_last_name:Valencia, totalorders:1
# customer_first_name:Effie, customer_last_name:Jenkins, totalorders:1
# customer_first_name:Efren, customer_last_name:Oliver, totalorders:1
# customer_first_name:Efren, customer_last_name:Whitfield, totalorders:1
# customer_first_name:Ehtel, customer_last_name:Cobb, totalorders:1
# customer_first_name:Elaina, customer_last_name:Key, totalorders:1
# customer_first_name:Elana, customer_last_name:Miles, totalorders:1
# customer_first_name:Elanor, customer_last_name:Patrick, totalorders:1
# customer_first_name:Eldridge, customer_last_name:Greer, totalorders:1
# customer_first_name:Eleanor, customer_last_name:Mendez, totalorders:1
# customer_first_name:Elease, customer_last_name:Dejesus, totalorders:1
# customer_first_name:Eleni, customer_last_name:Gordon, totalorders:1
# customer_first_name:Elenore, customer_last_name:Hensley, totalorders:1
# customer_first_name:Elenore, customer_last_name:William, totalorders:1
# customer_first_name:Eli, customer_last_name:Contreras, totalorders:1
# customer_first_name:Eliana, customer_last_name:Reese, totalorders:1
# customer_first_name:Eliana, customer_last_name:Silva, totalorders:1
# customer_first_name:Elinore, customer_last_name:Aguilar, totalorders:3
# customer_first_name:Eliseo, customer_last_name:Knight, totalorders:1
# customer_first_name:Eliz, customer_last_name:Lynch, totalorders:1
# customer_first_name:Eliz, customer_last_name:Whitney, totalorders:1
# customer_first_name:Ellena, customer_last_name:Clements, totalorders:1
# customer_first_name:Ellsworth, customer_last_name:Michael, totalorders:1
# customer_first_name:Elma, customer_last_name:Molina, totalorders:1
# customer_first_name:Elmira, customer_last_name:Levy, totalorders:1
# customer_first_name:Elmo, customer_last_name:Arnold, totalorders:1
# customer_first_name:Elmo, customer_last_name:Sweeney, totalorders:1
# customer_first_name:Elnora, customer_last_name:Simpson, totalorders:1
# customer_first_name:Eloisa, customer_last_name:Tucker, totalorders:1
# customer_first_name:Elouise, customer_last_name:Fry, totalorders:1
# customer_first_name:Elvera, customer_last_name:Peck, totalorders:2
# customer_first_name:Elvia, customer_last_name:Cardenas, totalorders:1
# customer_first_name:Elvina, customer_last_name:Gates, totalorders:1
# customer_first_name:Emanuel, customer_last_name:Mckee, totalorders:1
# customer_first_name:Emelda, customer_last_name:Dickerson, totalorders:1
# customer_first_name:Emmaline, customer_last_name:Huber, totalorders:1
# customer_first_name:Emmett, customer_last_name:Casey, totalorders:1
# customer_first_name:Emmett, customer_last_name:Hahn, totalorders:1
# customer_first_name:Emmitt, customer_last_name:Sanchez, totalorders:3
# customer_first_name:Emory, customer_last_name:O'connor, totalorders:1
# customer_first_name:Enoch, customer_last_name:Rosario, totalorders:1
# customer_first_name:Eric, customer_last_name:Hardin, totalorders:1
# customer_first_name:Erik, customer_last_name:Leblanc, totalorders:1
# customer_first_name:Erlene, customer_last_name:Cook, totalorders:1
# customer_first_name:Erlinda, customer_last_name:Humphrey, totalorders:1
# customer_first_name:Erlinda, customer_last_name:Nielsen, totalorders:1
# customer_first_name:Erlinda, customer_last_name:Osborne, totalorders:1
# customer_first_name:Erma, customer_last_name:Salinas, totalorders:1
# customer_first_name:Erna, customer_last_name:Sloan, totalorders:1
# customer_first_name:Ernest, customer_last_name:Rollins, totalorders:1
# customer_first_name:Ernestina, customer_last_name:Skinner, totalorders:1
# customer_first_name:Ester, customer_last_name:Acevedo, totalorders:1
# customer_first_name:Ethelyn, customer_last_name:Ray, totalorders:1
# customer_first_name:Etsuko, customer_last_name:Garrison, totalorders:1
# customer_first_name:Eun, customer_last_name:Harris, totalorders:1
# customer_first_name:Euna, customer_last_name:Lopez, totalorders:1
# customer_first_name:Evelin, customer_last_name:Vargas, totalorders:1
# customer_first_name:Evelina, customer_last_name:Byrd, totalorders:1
# customer_first_name:Evelina, customer_last_name:Manning, totalorders:1
# customer_first_name:Everett, customer_last_name:Vega, totalorders:1
# customer_first_name:Ezra, customer_last_name:Fowler, totalorders:1
# customer_first_name:Ezra, customer_last_name:Silva, totalorders:1
# customer_first_name:Fairy, customer_last_name:Robinson, totalorders:1
# customer_first_name:Fannie, customer_last_name:Jenkins, totalorders:1
# customer_first_name:Farrah, customer_last_name:Orr, totalorders:1
# customer_first_name:Faustino, customer_last_name:Delacruz, totalorders:1
# customer_first_name:Felica, customer_last_name:Munoz, totalorders:1
# customer_first_name:Felice, customer_last_name:Guzman, totalorders:2
# customer_first_name:Felicidad, customer_last_name:Golden, totalorders:1
# customer_first_name:Ferne, customer_last_name:Kline, totalorders:1
# customer_first_name:Florencio, customer_last_name:Davenport, totalorders:1
# customer_first_name:Floretta, customer_last_name:Higgins, totalorders:1
# customer_first_name:Florrie, customer_last_name:Little, totalorders:1
# customer_first_name:Flossie, customer_last_name:Holder, totalorders:1
# customer_first_name:Fran, customer_last_name:Yang, totalorders:2
# customer_first_name:Fransisca, customer_last_name:Nicholson, totalorders:1
# customer_first_name:Freddie, customer_last_name:Mathis, totalorders:1
# customer_first_name:Frederica, customer_last_name:Rojas, totalorders:1
# customer_first_name:Gabriel, customer_last_name:Pitts, totalorders:1
# customer_first_name:Gabriel, customer_last_name:Wagner, totalorders:1
# customer_first_name:Gabriela, customer_last_name:Warren, totalorders:1
# customer_first_name:Gabriella, customer_last_name:Jones, totalorders:1
# customer_first_name:Garland, customer_last_name:Weaver, totalorders:1
# customer_first_name:Garret, customer_last_name:Clay, totalorders:1
# customer_first_name:Garry, customer_last_name:Espinoza, totalorders:3
# customer_first_name:Garry, customer_last_name:Juarez, totalorders:1
# customer_first_name:Garth, customer_last_name:Huff, totalorders:1
# customer_first_name:Gayla, customer_last_name:Sims, totalorders:1
# customer_first_name:Gayle, customer_last_name:Wilkinson, totalorders:1
# customer_first_name:Gena, customer_last_name:Owens, totalorders:1
# customer_first_name:Genevie, customer_last_name:Miles, totalorders:1
# customer_first_name:Genevieve, customer_last_name:Juarez, totalorders:1
# customer_first_name:Genny, customer_last_name:Fields, totalorders:1
# customer_first_name:Genny, customer_last_name:Hensley, totalorders:1
# customer_first_name:Genoveva, customer_last_name:Baldwin, totalorders:3
# customer_first_name:Genoveva, customer_last_name:Lloyd, totalorders:1
# customer_first_name:Genoveva, customer_last_name:Tyler, totalorders:1
# customer_first_name:George, customer_last_name:Pickett, totalorders:1
# customer_first_name:Georgeann, customer_last_name:Rojas, totalorders:1
# customer_first_name:Georgeann, customer_last_name:Waller, totalorders:2
# customer_first_name:Georgeanna, customer_last_name:Webster, totalorders:1
# customer_first_name:Georgetta, customer_last_name:Hardin, totalorders:3
# customer_first_name:Georgina, customer_last_name:Gonzales, totalorders:1
# customer_first_name:Geraldine, customer_last_name:O'donnell, totalorders:1
# customer_first_name:Gertha, customer_last_name:Mejia, totalorders:1
# customer_first_name:Gertrud, customer_last_name:Rhodes, totalorders:2
# customer_first_name:Gertrude, customer_last_name:Terry, totalorders:1
# customer_first_name:Ghislaine, customer_last_name:Compton, totalorders:1
# customer_first_name:Gilbert, customer_last_name:Calhoun, totalorders:1
# customer_first_name:Gilberte, customer_last_name:Duke, totalorders:1
# customer_first_name:Gilberto, customer_last_name:Parsons, totalorders:1
# customer_first_name:Gilberto, customer_last_name:Sanders, totalorders:1
# customer_first_name:Gilma, customer_last_name:Dejesus, totalorders:1
# customer_first_name:Ginette, customer_last_name:Edwards, totalorders:1
# customer_first_name:Giovanna, customer_last_name:Jefferson, totalorders:1
# customer_first_name:Giselle, customer_last_name:Robles, totalorders:1
# customer_first_name:Glady, customer_last_name:Wells, totalorders:1
# customer_first_name:Grace, customer_last_name:Madden, totalorders:1
# customer_first_name:Graciela, customer_last_name:Barber, totalorders:2
# customer_first_name:Graig, customer_last_name:Cannon, totalorders:1
# customer_first_name:Graig, customer_last_name:Roth, totalorders:1
# customer_first_name:Greta, customer_last_name:Page, totalorders:1
# customer_first_name:Grisel, customer_last_name:Maynard, totalorders:1
# customer_first_name:Guillermina, customer_last_name:Noble, totalorders:2
# customer_first_name:Guillermo, customer_last_name:Hart, totalorders:1
# customer_first_name:Gussie, customer_last_name:Harding, totalorders:1
# customer_first_name:Gustavo, customer_last_name:Gamble, totalorders:1
# customer_first_name:Gwendolyn, customer_last_name:Miller, totalorders:1
# customer_first_name:Gwenn, customer_last_name:Melton, totalorders:1
# customer_first_name:Hae, customer_last_name:Ramirez, totalorders:1
# customer_first_name:Han, customer_last_name:Schneider, totalorders:1
# customer_first_name:Han, customer_last_name:Wade, totalorders:1
# customer_first_name:Hans, customer_last_name:Price, totalorders:1
# customer_first_name:Harold, customer_last_name:O'connor, totalorders:1
# customer_first_name:Harris, customer_last_name:Pittman, totalorders:1
# customer_first_name:Hassan, customer_last_name:Nash, totalorders:1
# customer_first_name:Hayden, customer_last_name:Cross, totalorders:1
# customer_first_name:Heather, customer_last_name:Chaney, totalorders:1
# customer_first_name:Heather, customer_last_name:Perry, totalorders:1
# customer_first_name:Hedwig, customer_last_name:Paul, totalorders:2
# customer_first_name:Hee, customer_last_name:Greer, totalorders:1
# customer_first_name:Heide, customer_last_name:Reed, totalorders:1
# customer_first_name:Henrietta, customer_last_name:Wagner, totalorders:1
# customer_first_name:Herlinda, customer_last_name:Stone, totalorders:1
# customer_first_name:Hermila, customer_last_name:Mckay, totalorders:1
# customer_first_name:Herminia, customer_last_name:Reyes, totalorders:1
# customer_first_name:Herta, customer_last_name:Rollins, totalorders:1
# customer_first_name:Hilary, customer_last_name:Savage, totalorders:1
# customer_first_name:Hilda, customer_last_name:Harvey, totalorders:1
# customer_first_name:Hilde, customer_last_name:Nieves, totalorders:1
# customer_first_name:Hildegarde, customer_last_name:Christensen, totalorders:1
# customer_first_name:Hipolito, customer_last_name:Padilla, totalorders:1
# customer_first_name:Hollis, customer_last_name:Rasmussen, totalorders:1
# customer_first_name:Holly, customer_last_name:Nieves, totalorders:1
# customer_first_name:Homer, customer_last_name:Powers, totalorders:1
# customer_first_name:Honey, customer_last_name:Camacho, totalorders:1
# customer_first_name:Hope, customer_last_name:Cotton, totalorders:1
# customer_first_name:Hortencia, customer_last_name:Graham, totalorders:1
# customer_first_name:Hortencia, customer_last_name:O'neil, totalorders:1
# customer_first_name:Houston, customer_last_name:Vasquez, totalorders:1
# customer_first_name:Hubert, customer_last_name:Reilly, totalorders:1
# customer_first_name:Hubert, customer_last_name:Stone, totalorders:1
# customer_first_name:Hue, customer_last_name:Dalton, totalorders:1
# customer_first_name:Hue, customer_last_name:May, totalorders:1
# customer_first_name:Hugh, customer_last_name:Craft, totalorders:1
# customer_first_name:Hye, customer_last_name:Mercer, totalorders:1
# customer_first_name:Ilda, customer_last_name:Roberson, totalorders:1
# customer_first_name:Ileana, customer_last_name:Holt, totalorders:1
# customer_first_name:Ilona, customer_last_name:Spears, totalorders:1
# customer_first_name:India, customer_last_name:Barron, totalorders:1
# customer_first_name:Inez, customer_last_name:Snider, totalorders:1
# customer_first_name:Inga, customer_last_name:Koch, totalorders:1
# customer_first_name:Inge, customer_last_name:Olsen, totalorders:1
# customer_first_name:Ingeborg, customer_last_name:Ellison, totalorders:1
# customer_first_name:Inger, customer_last_name:Jennings, totalorders:1
# customer_first_name:Inocencia, customer_last_name:Key, totalorders:1
# customer_first_name:Iola, customer_last_name:Rasmussen, totalorders:1
# customer_first_name:Ira, customer_last_name:Erickson, totalorders:1
# customer_first_name:Ira, customer_last_name:Moore, totalorders:1
# customer_first_name:Irving, customer_last_name:Pitts, totalorders:1
# customer_first_name:Iva, customer_last_name:Wilcox, totalorders:1
# customer_first_name:Ivelisse, customer_last_name:Nixon, totalorders:1
# customer_first_name:Ivette, customer_last_name:Estes, totalorders:1
# customer_first_name:Ivette, customer_last_name:Warren, totalorders:1
# customer_first_name:Ivonne, customer_last_name:Yang, totalorders:1
# customer_first_name:Izola, customer_last_name:Hobbs, totalorders:1
# customer_first_name:Ja, customer_last_name:Dillard, totalorders:1
# customer_first_name:Jacalyn, customer_last_name:Barnett, totalorders:1
# customer_first_name:Jackeline, customer_last_name:Colon, totalorders:1
# customer_first_name:Jacquline, customer_last_name:Duncan, totalorders:3
# customer_first_name:Jaimee, customer_last_name:Day, totalorders:1
# customer_first_name:Jama, customer_last_name:Rodriquez, totalorders:1
# customer_first_name:Jamaal, customer_last_name:Albert, totalorders:3
# customer_first_name:Jamaal, customer_last_name:Baker, totalorders:1
# customer_first_name:Jamaal, customer_last_name:Morrison, totalorders:1
# customer_first_name:Jame, customer_last_name:Riggs, totalorders:1
# customer_first_name:James, customer_last_name:Robles, totalorders:1
# customer_first_name:Jamika, customer_last_name:Acevedo, totalorders:1
# customer_first_name:Jamika, customer_last_name:Blanchard, totalorders:1
# customer_first_name:Jana, customer_last_name:Thomas, totalorders:1
# customer_first_name:Janae, customer_last_name:Doyle, totalorders:1
# customer_first_name:Jane, customer_last_name:Henderson, totalorders:1
# customer_first_name:Janella, customer_last_name:Bright, totalorders:1
# customer_first_name:Janelle, customer_last_name:Maldonado, totalorders:1
# customer_first_name:Janetta, customer_last_name:Aguirre, totalorders:2
# customer_first_name:Janie, customer_last_name:Herrera, totalorders:1
# customer_first_name:Janine, customer_last_name:Manning, totalorders:1
# customer_first_name:Janna, customer_last_name:Hayden, totalorders:1
# customer_first_name:Jaqueline, customer_last_name:Cummings, totalorders:1
# customer_first_name:Jasmin, customer_last_name:Young, totalorders:1
# customer_first_name:Jasper, customer_last_name:Castro, totalorders:1
# customer_first_name:Javier, customer_last_name:Nichols, totalorders:1
# customer_first_name:Jayme, customer_last_name:Zamora, totalorders:1
# customer_first_name:Jayne, customer_last_name:Kirkland, totalorders:3
# customer_first_name:Jayson, customer_last_name:Rutledge, totalorders:1
# customer_first_name:Jeanett, customer_last_name:Herman, totalorders:1
# customer_first_name:Jeanice, customer_last_name:Frost, totalorders:2
# customer_first_name:Jeanie, customer_last_name:Kirkland, totalorders:2
# customer_first_name:Jeannette, customer_last_name:Skinner, totalorders:1
# customer_first_name:Jeannie, customer_last_name:Wilcox, totalorders:1
# customer_first_name:Jeffrey, customer_last_name:Hill, totalorders:1
# customer_first_name:Jeffry, customer_last_name:Church, totalorders:1
# customer_first_name:Jenee, customer_last_name:Rasmussen, totalorders:2
# customer_first_name:Jenell, customer_last_name:Crosby, totalorders:1
# customer_first_name:Jeni, customer_last_name:Booker, totalorders:2
# customer_first_name:Jeni, customer_last_name:Farley, totalorders:1
# customer_first_name:Jeniffer, customer_last_name:Ratliff, totalorders:1
# customer_first_name:Jeniffer, customer_last_name:Slater, totalorders:1
# customer_first_name:Jenine, customer_last_name:Crane, totalorders:1
# customer_first_name:Jenine, customer_last_name:Dawson, totalorders:1
# customer_first_name:Jenise, customer_last_name:Preston, totalorders:1
# customer_first_name:Jenna, customer_last_name:Saunders, totalorders:1
# customer_first_name:Jennell, customer_last_name:Solis, totalorders:1
# customer_first_name:Jennette, customer_last_name:Baker, totalorders:1
# customer_first_name:Jennette, customer_last_name:Wooten, totalorders:1
# customer_first_name:Jennie, customer_last_name:Middleton, totalorders:1
# customer_first_name:Jenniffer, customer_last_name:Bullock, totalorders:1
# customer_first_name:Jenny, customer_last_name:Bell, totalorders:1
# customer_first_name:Jerald, customer_last_name:Blackwell, totalorders:1
# customer_first_name:Jerlene, customer_last_name:Rios, totalorders:1
# customer_first_name:Jerome, customer_last_name:Bolton, totalorders:1
# customer_first_name:Jeromy, customer_last_name:Burch, totalorders:2
# customer_first_name:Jeromy, customer_last_name:Elliott, totalorders:1
# customer_first_name:Jerri, customer_last_name:Guthrie, totalorders:1
# customer_first_name:Jerri, customer_last_name:Henry, totalorders:1
# customer_first_name:Jesica, customer_last_name:Fields, totalorders:1
# customer_first_name:Jessika, customer_last_name:Bray, totalorders:1
# customer_first_name:Jesus, customer_last_name:Burch, totalorders:1
# customer_first_name:Jewel, customer_last_name:Sparks, totalorders:1
# customer_first_name:Jewell, customer_last_name:Reyes, totalorders:1
# customer_first_name:Ji, customer_last_name:Burt, totalorders:1
# customer_first_name:Jimmy, customer_last_name:Russell, totalorders:1
# customer_first_name:Jina, customer_last_name:Cooper, totalorders:1
# customer_first_name:Joann, customer_last_name:Barber, totalorders:1
# customer_first_name:Joaquin, customer_last_name:Hawkins, totalorders:1
# customer_first_name:Joe, customer_last_name:Melton, totalorders:1
# customer_first_name:Joeann, customer_last_name:Garrison, totalorders:1
# customer_first_name:Joel, customer_last_name:Wynn, totalorders:1
# customer_first_name:Joesph, customer_last_name:Delacruz, totalorders:2
# customer_first_name:Johana, customer_last_name:Jacobson, totalorders:1
# customer_first_name:Johna, customer_last_name:Powers, totalorders:1
# customer_first_name:Johnathan, customer_last_name:Velazquez, totalorders:1
# customer_first_name:Joi, customer_last_name:Reeves, totalorders:1
# customer_first_name:Jone, customer_last_name:Bernard, totalorders:2
# customer_first_name:Jonell, customer_last_name:Rivas, totalorders:1
# customer_first_name:Jong, customer_last_name:Guthrie, totalorders:1
# customer_first_name:Joni, customer_last_name:Lee, totalorders:1
# customer_first_name:Jonna, customer_last_name:Brown, totalorders:1
# customer_first_name:Josef, customer_last_name:Greer, totalorders:1
# customer_first_name:Josephine, customer_last_name:Dale, totalorders:1
# customer_first_name:Josh, customer_last_name:Shaw, totalorders:1
# customer_first_name:Joshua, customer_last_name:Berg, totalorders:1
# customer_first_name:Joshua, customer_last_name:Robertson, totalorders:1
# customer_first_name:Josie, customer_last_name:Schultz, totalorders:1
# customer_first_name:Jovita, customer_last_name:Bishop, totalorders:1
# customer_first_name:Joy, customer_last_name:Underwood, totalorders:1
# customer_first_name:Judith, customer_last_name:Finley, totalorders:1
# customer_first_name:Jule, customer_last_name:Davenport, totalorders:1
# customer_first_name:Julee, customer_last_name:Woodard, totalorders:1
# customer_first_name:Julia, customer_last_name:Joyner, totalorders:1
# customer_first_name:Juliane, customer_last_name:Dillard, totalorders:1
# customer_first_name:Julianne, customer_last_name:Shannon, totalorders:1
# customer_first_name:Julienne, customer_last_name:Moody, totalorders:1
# customer_first_name:Julius, customer_last_name:Holt, totalorders:1
# customer_first_name:Junita, customer_last_name:Reese, totalorders:1
# customer_first_name:Justa, customer_last_name:Thompson, totalorders:1
# customer_first_name:Justin, customer_last_name:Newton, totalorders:1
# ...
# customer_first_name:Shauna, customer_last_name:Edwards, totalorders:1
# customer_first_name:Shaunda, customer_last_name:Barnett, totalorders:1
# customer_first_name:Shawnda, customer_last_name:Glover, totalorders:1
# customer_first_name:Shawnna, customer_last_name:Frank, totalorders:1
# customer_first_name:Shay, customer_last_name:Stephenson, totalorders:1
# customer_first_name:Shayla, customer_last_name:Hart, totalorders:1
# customer_first_name:Shea, customer_last_name:Howell, totalorders:1
# customer_first_name:Sheba, customer_last_name:Knapp, totalorders:1
# customer_first_name:Sheila, customer_last_name:Goodman, totalorders:1
# customer_first_name:Sheila, customer_last_name:Travis, totalorders:1
# customer_first_name:Shemeka, customer_last_name:Lyons, totalorders:1
# customer_first_name:Shena, customer_last_name:Carter, totalorders:1
# customer_first_name:Shenna, customer_last_name:Benton, totalorders:1
# customer_first_name:Shenna, customer_last_name:Espinoza, totalorders:1
# customer_first_name:Sheree, customer_last_name:Blanchard, totalorders:1
# customer_first_name:Sheree, customer_last_name:Pena, totalorders:1
# customer_first_name:Sheri, customer_last_name:Cole, totalorders:1
# customer_first_name:Sherie, customer_last_name:Ayala, totalorders:1
# customer_first_name:Sherilyn, customer_last_name:Wilcox, totalorders:1
# customer_first_name:Sherise, customer_last_name:Mercer, totalorders:1
# customer_first_name:Sherita, customer_last_name:Cherry, totalorders:1
# customer_first_name:Sherril, customer_last_name:Alvarado, totalorders:1
# customer_first_name:Shery, customer_last_name:Acosta, totalorders:1
# customer_first_name:Shery, customer_last_name:Randolph, totalorders:1
# customer_first_name:Sheryl, customer_last_name:Chase, totalorders:1
# customer_first_name:Shiela, customer_last_name:Calderon, totalorders:1
# customer_first_name:Shila, customer_last_name:White, totalorders:1
# customer_first_name:Shiloh, customer_last_name:Bates, totalorders:1
# customer_first_name:Shiloh, customer_last_name:Reeves, totalorders:1
# customer_first_name:Shirely, customer_last_name:Cantrell, totalorders:1
# customer_first_name:Shirely, customer_last_name:Stanley, totalorders:1
# customer_first_name:Shona, customer_last_name:Mcmillan, totalorders:1
# customer_first_name:Shonta, customer_last_name:Mercer, totalorders:1
# customer_first_name:Shonta, customer_last_name:Preston, totalorders:1
# customer_first_name:Shu, customer_last_name:Mays, totalorders:1
# customer_first_name:Silas, customer_last_name:Tate, totalorders:1
# customer_first_name:Sindy, customer_last_name:Anderson, totalorders:1
# customer_first_name:Siobhan, customer_last_name:Lang, totalorders:1
# customer_first_name:Skye, customer_last_name:Pope, totalorders:1
# customer_first_name:Soledad, customer_last_name:Moses, totalorders:1
# customer_first_name:Somer, customer_last_name:Jordan, totalorders:1
# customer_first_name:Sommer, customer_last_name:Hopkins, totalorders:1
# customer_first_name:Son, customer_last_name:Warner, totalorders:1
# customer_first_name:Sonja, customer_last_name:Walls, totalorders:1
# customer_first_name:Sophia, customer_last_name:Mcmillan, totalorders:1
# customer_first_name:Spring, customer_last_name:Hayes, totalorders:1
# customer_first_name:Stacie, customer_last_name:Sims, totalorders:1
# customer_first_name:Stan, customer_last_name:Saunders, totalorders:1
# customer_first_name:Starr, customer_last_name:Schneider, totalorders:1
# customer_first_name:Stefani, customer_last_name:Gamble, totalorders:1
# customer_first_name:Stefany, customer_last_name:Potter, totalorders:1
# customer_first_name:Stephaine, customer_last_name:Riddle, totalorders:1
# customer_first_name:Stephanie, customer_last_name:Browning, totalorders:1
# customer_first_name:Stephen, customer_last_name:Vega, totalorders:1
# customer_first_name:Steve, customer_last_name:Bender, totalorders:1
# customer_first_name:Suellen, customer_last_name:Mercado, totalorders:1
# customer_first_name:Sung, customer_last_name:Chambers, totalorders:1
# customer_first_name:Sunshine, customer_last_name:Rosario, totalorders:1
# customer_first_name:Susann, customer_last_name:Bass, totalorders:1
# customer_first_name:Susannah, customer_last_name:Fields, totalorders:1
# customer_first_name:Sylvester, customer_last_name:Chan, totalorders:1
# customer_first_name:Sylvie, customer_last_name:Wilkerson, totalorders:1
# customer_first_name:Syreeta, customer_last_name:Hendricks, totalorders:2
# customer_first_name:Tad, customer_last_name:Gardner, totalorders:1
# customer_first_name:Taisha, customer_last_name:Vang, totalorders:1
# customer_first_name:Tajuana, customer_last_name:Riddle, totalorders:1
# customer_first_name:Tajuana, customer_last_name:Rollins, totalorders:1
# customer_first_name:Takako, customer_last_name:Casey, totalorders:2
# customer_first_name:Tam, customer_last_name:Fisher, totalorders:1
# customer_first_name:Tama, customer_last_name:Berg, totalorders:1
# customer_first_name:Tameka, customer_last_name:Fisher, totalorders:3
# customer_first_name:Tamela, customer_last_name:Harrell, totalorders:1
# customer_first_name:Tammera, customer_last_name:Fischer, totalorders:1
# customer_first_name:Tammie, customer_last_name:Cherry, totalorders:1
# customer_first_name:Tammy, customer_last_name:Austin, totalorders:1
# customer_first_name:Tanesha, customer_last_name:Hampton, totalorders:1
# customer_first_name:Tanesha, customer_last_name:Sawyer, totalorders:1
# customer_first_name:Tangela, customer_last_name:Hurley, totalorders:1
# customer_first_name:Tangela, customer_last_name:Quinn, totalorders:2
# customer_first_name:Tania, customer_last_name:Swanson, totalorders:1
# customer_first_name:Tara, customer_last_name:Maynard, totalorders:1
# customer_first_name:Tarra, customer_last_name:Guerrero, totalorders:1
# customer_first_name:Taylor, customer_last_name:Cole, totalorders:1
# customer_first_name:Tayna, customer_last_name:Wade, totalorders:1
# customer_first_name:Tempie, customer_last_name:Jacobson, totalorders:1
# customer_first_name:Tena, customer_last_name:Cruz, totalorders:2
# customer_first_name:Tena, customer_last_name:Huber, totalorders:1
# customer_first_name:Tenisha, customer_last_name:Lyons, totalorders:2
# customer_first_name:Teofila, customer_last_name:Fischer, totalorders:2
# customer_first_name:Tereasa, customer_last_name:Bird, totalorders:1
# customer_first_name:Terese, customer_last_name:Briggs, totalorders:1
# customer_first_name:Terese, customer_last_name:Palmer, totalorders:1
# customer_first_name:Terra, customer_last_name:Pickett, totalorders:1
# customer_first_name:Terrance, customer_last_name:Lynn, totalorders:1
# customer_first_name:Terrell, customer_last_name:Mathis, totalorders:1
# customer_first_name:Tessie, customer_last_name:Farmer, totalorders:1
# customer_first_name:Thad, customer_last_name:Castro, totalorders:1
# customer_first_name:Thad, customer_last_name:Gilliam, totalorders:1
# customer_first_name:Thalia, customer_last_name:Dillard, totalorders:2
# customer_first_name:Thalia, customer_last_name:Horne, totalorders:1
# customer_first_name:Thanh, customer_last_name:Figueroa, totalorders:1
# customer_first_name:Theo, customer_last_name:Reese, totalorders:2
# customer_first_name:Theresia, customer_last_name:Barron, totalorders:1
# customer_first_name:Thurman, customer_last_name:Ellis, totalorders:1
# customer_first_name:Tiana, customer_last_name:Henderson, totalorders:1
# customer_first_name:Tiesha, customer_last_name:Daniel, totalorders:2
# customer_first_name:Tilda, customer_last_name:Melton, totalorders:1
# customer_first_name:Timothy, customer_last_name:Byers, totalorders:1
# customer_first_name:Tina, customer_last_name:Bush, totalorders:1
# customer_first_name:Tiny, customer_last_name:French, totalorders:1
# customer_first_name:Tisa, customer_last_name:Whitney, totalorders:1
# customer_first_name:Tisha, customer_last_name:Petty, totalorders:1
# customer_first_name:Titus, customer_last_name:Bullock, totalorders:2
# customer_first_name:Tobie, customer_last_name:Little, totalorders:3
# customer_first_name:Todd, customer_last_name:Waters, totalorders:1
# customer_first_name:Tomasa, customer_last_name:Carson, totalorders:2
# customer_first_name:Tomeka, customer_last_name:Higgins, totalorders:1
# customer_first_name:Tomika, customer_last_name:Larson, totalorders:1
# customer_first_name:Tomika, customer_last_name:Wilder, totalorders:1
# customer_first_name:Tommie, customer_last_name:Cooley, totalorders:1
# customer_first_name:Tommie, customer_last_name:Melton, totalorders:2
# customer_first_name:Tona, customer_last_name:Velasquez, totalorders:1
# customer_first_name:Tonda, customer_last_name:Armstrong, totalorders:1
# customer_first_name:Tonda, customer_last_name:Webb, totalorders:1
# customer_first_name:Tonisha, customer_last_name:Fowler, totalorders:1
# customer_first_name:Tonja, customer_last_name:Bean, totalorders:1
# customer_first_name:Tonja, customer_last_name:Henderson, totalorders:1
# customer_first_name:Tony, customer_last_name:Hicks, totalorders:1
# customer_first_name:Tora, customer_last_name:Dunlap, totalorders:1
# customer_first_name:Toshia, customer_last_name:Cardenas, totalorders:1
# customer_first_name:Toya, customer_last_name:Pratt, totalorders:1
# customer_first_name:Trang, customer_last_name:Hardin, totalorders:1
# customer_first_name:Travis, customer_last_name:Goodman, totalorders:1
# customer_first_name:Travis, customer_last_name:Whitley, totalorders:1
# customer_first_name:Treasa, customer_last_name:Dickerson, totalorders:1
# customer_first_name:Trena, customer_last_name:Hudson, totalorders:1
# customer_first_name:Trena, customer_last_name:Rogers, totalorders:1
# customer_first_name:Tressa, customer_last_name:Weiss, totalorders:1
# customer_first_name:Tricia, customer_last_name:Daniels, totalorders:1
# customer_first_name:Trinidad, customer_last_name:Chapman, totalorders:1
# customer_first_name:Trinidad, customer_last_name:Mcclain, totalorders:1
# customer_first_name:Trinity, customer_last_name:Riddle, totalorders:1
# customer_first_name:Trisha, customer_last_name:Johnson, totalorders:1
# customer_first_name:Trista, customer_last_name:Lambert, totalorders:1
# customer_first_name:Trudy, customer_last_name:Riddle, totalorders:1
# customer_first_name:Tu, customer_last_name:Ramirez, totalorders:2
# customer_first_name:Tuan, customer_last_name:Wolfe, totalorders:1
# customer_first_name:Tuyet, customer_last_name:Rosa, totalorders:1
# customer_first_name:Twana, customer_last_name:Arnold, totalorders:1
# customer_first_name:Ulrike, customer_last_name:Chan, totalorders:1
# customer_first_name:Ulysses, customer_last_name:Gaines, totalorders:1
# customer_first_name:Valentin, customer_last_name:Mclaughlin, totalorders:1
# customer_first_name:Valeri, customer_last_name:Marshall, totalorders:1
# customer_first_name:Valery, customer_last_name:Saunders, totalorders:1
# customer_first_name:Vallie, customer_last_name:Dixon, totalorders:1
# customer_first_name:Van, customer_last_name:Peters, totalorders:1
# customer_first_name:Vance, customer_last_name:Taylor, totalorders:1
# customer_first_name:Vanda, customer_last_name:Holmes, totalorders:1
# customer_first_name:Vanessa, customer_last_name:West, totalorders:1
# customer_first_name:Vashti, customer_last_name:Rosario, totalorders:1
# customer_first_name:Venessa, customer_last_name:Frost, totalorders:1
# customer_first_name:Venus, customer_last_name:Hewitt, totalorders:1
# customer_first_name:Verda, customer_last_name:Gilbert, totalorders:1
# customer_first_name:Verdell, customer_last_name:Joyner, totalorders:1
# customer_first_name:Verna, customer_last_name:Solis, totalorders:1
# customer_first_name:Vernell, customer_last_name:Goff, totalorders:1
# customer_first_name:Vernetta, customer_last_name:Banks, totalorders:1
# customer_first_name:Vernia, customer_last_name:Madden, totalorders:1
# customer_first_name:Vernita, customer_last_name:Ball, totalorders:1
# customer_first_name:Vernon, customer_last_name:Knowles, totalorders:1
# customer_first_name:Verona, customer_last_name:O'neill, totalorders:1
# customer_first_name:Veronika, customer_last_name:Rollins, totalorders:1
# customer_first_name:Veronique, customer_last_name:Fulton, totalorders:1
# customer_first_name:Vicki, customer_last_name:Wiggins, totalorders:1
# customer_first_name:Victor, customer_last_name:Pittman, totalorders:1
# customer_first_name:Vikki, customer_last_name:Erickson, totalorders:1
# customer_first_name:Vince, customer_last_name:Schneider, totalorders:1
# customer_first_name:Vinnie, customer_last_name:Chan, totalorders:1
# customer_first_name:Violet, customer_last_name:Valenzuela, totalorders:1
# customer_first_name:Virgen, customer_last_name:Clemons, totalorders:1
# customer_first_name:Virgil, customer_last_name:Frost, totalorders:1
# customer_first_name:Virgina, customer_last_name:Berg, totalorders:1
# customer_first_name:Vito, customer_last_name:Pickett, totalorders:1
# customer_first_name:Viva, customer_last_name:Dawson, totalorders:1
# customer_first_name:Vivian, customer_last_name:Deleon, totalorders:1
# customer_first_name:Vonda, customer_last_name:Berger, totalorders:1
# customer_first_name:Wai, customer_last_name:Soto, totalorders:1
# customer_first_name:Waldo, customer_last_name:Hart, totalorders:1
# customer_first_name:Wallace, customer_last_name:Lane, totalorders:1
# customer_first_name:Walton, customer_last_name:Dejesus, totalorders:1
# customer_first_name:Wanita, customer_last_name:Davenport, totalorders:1
# customer_first_name:Weldon, customer_last_name:Michael, totalorders:1
# customer_first_name:Wendie, customer_last_name:Nash, totalorders:1
# customer_first_name:Wes, customer_last_name:Stanton, totalorders:1
# customer_first_name:Whitley, customer_last_name:Cannon, totalorders:1
# customer_first_name:Whitney, customer_last_name:Cash, totalorders:1
# customer_first_name:Whitney, customer_last_name:Estes, totalorders:1
# customer_first_name:Wilda, customer_last_name:Petersen, totalorders:1
# customer_first_name:Willetta, customer_last_name:Murphy, totalorders:1
# customer_first_name:Willian, customer_last_name:Hardin, totalorders:1
# customer_first_name:Williemae, customer_last_name:Holloway, totalorders:3
# customer_first_name:Willis, customer_last_name:Randolph, totalorders:1
# customer_first_name:Willow, customer_last_name:Gardner, totalorders:1
# customer_first_name:Winfred, customer_last_name:Harris, totalorders:1
# customer_first_name:Wm, customer_last_name:Pope, totalorders:1
# customer_first_name:Wynona, customer_last_name:Douglas, totalorders:1
# customer_first_name:Yahaira, customer_last_name:Robertson, totalorders:1
# customer_first_name:Yan, customer_last_name:Mcgowan, totalorders:2
# customer_first_name:Yan, customer_last_name:Trevino, totalorders:1
# customer_first_name:Yang, customer_last_name:Giles, totalorders:1
# customer_first_name:Yang, customer_last_name:Roth, totalorders:1
# customer_first_name:Yanira, customer_last_name:Bradshaw, totalorders:1
# customer_first_name:Yevette, customer_last_name:Elliott, totalorders:1
# customer_first_name:Yevette, customer_last_name:Todd, totalorders:1
# customer_first_name:Yolando, customer_last_name:Wade, totalorders:1
# customer_first_name:Yu, customer_last_name:Mcdonald, totalorders:1
# customer_first_name:Yuk, customer_last_name:Vega, totalorders:1
# customer_first_name:Yun, customer_last_name:Nelson, totalorders:1
# customer_first_name:Yvette, customer_last_name:Rogers, totalorders:1
# customer_first_name:Yvone, customer_last_name:Guerrero, totalorders:1
# customer_first_name:Yvone, customer_last_name:Yates, totalorders:1
# customer_first_name:Yvonne, customer_last_name:Bean, totalorders:1
# customer_first_name:Zelda, customer_last_name:Pratt, totalorders:1
# customer_first_name:Zella, customer_last_name:Fernandez, totalorders:1
# customer_first_name:Zelma, customer_last_name:Browning, totalorders:2
# customer_first_name:Zenia, customer_last_name:Bruce, totalorders:1
# customer_first_name:Zina, customer_last_name:Bonner, totalorders:2
# customer_first_name:Zona, customer_last_name:Cameron, totalorders:1
# customer_first_name:Zora, customer_last_name:Ford, totalorders:1
# customer_first_name:Zoraida, customer_last_name:Patton, totalorders:1
# customer_first_name:Zulema, customer_last_name:Browning, totalorders:1
# customer_first_name:Zulema, customer_last_name:Clemons, totalorders:1

# %% [markdown]
# ### Task 5: Retrieve products with stock quantities less than 50.

# %%
query="""select products.product_name,sum(stocks.quantity)as totalquantity
from products
join stocks
on products.product_id=stocks.product_id
group by products.product_name
having totalquantity < 50
"""
cursor.execute(query)
rows=cursor.fetchall()
for row in rows:
    print(f"product_name:{row[0]}, totalquantity:{row[1]}")
# Out:
# product_name:Electra Amsterdam Fashion 3i Ladies' - 2017/2018, totalquantity:47
# product_name:Electra Amsterdam Original 3i - 2015/2017, totalquantity:11
# product_name:Electra Amsterdam Original 3i Ladies' - 2017, totalquantity:12
# product_name:Electra Amsterdam Royal 8i - 2017/2018, totalquantity:45
# product_name:Electra Amsterdam Royal 8i Ladies - 2018, totalquantity:26
# product_name:Electra Cruiser 1 - 2016/2017/2018, totalquantity:34
# product_name:Electra Cruiser 1 Ladies' - 2018, totalquantity:10
# product_name:Electra Cruiser 7D Ladies' - 2016/2018, totalquantity:44
# product_name:Electra Cruiser Lux 1 - 2017, totalquantity:49
# product_name:Electra Cruiser Lux 3i - 2018, totalquantity:39
# product_name:Electra Cruiser Lux 3i Ladies' - 2018, totalquantity:39
# product_name:Electra Cruiser Lux 7D - 2018, totalquantity:43
# product_name:Electra Cruiser Lux 7D Ladies' - 2018, totalquantity:32
# product_name:Electra Cruiser Lux Fat Tire 7D - 2018, totalquantity:39
# product_name:Electra Cyclosaurus 1 (16-inch) - Boy's - 2018, totalquantity:32
# product_name:Electra Daydreamer 3i Ladies' - 2018, totalquantity:49
# product_name:Electra Delivery 3i - 2016/2017/2018, totalquantity:47
# product_name:Electra Girl's Hawaii 1 (20-inch) - 2015/2016, totalquantity:29
# product_name:Electra Heartchya 1 (20-inch) - Girl's - 2018, totalquantity:39
# product_name:Electra Koa 3i Ladies' - 2018, totalquantity:12
# product_name:Electra Morningstar 3i Ladies' - 2018, totalquantity:28
# product_name:Electra Moto 1 - 2016, totalquantity:31
# product_name:Electra Moto 3i (20-inch) - Boy's - 2017, totalquantity:43
# product_name:Electra Queen of Hearts 3i - 2018, totalquantity:24
# product_name:Electra Soft Serve 1 (16-inch) - Girl's - 2018, totalquantity:44
# product_name:Electra Starship 1 16" - 2018, totalquantity:38
# product_name:Electra Straight 8 1 (16-inch) - Boy's - 2018, totalquantity:43
# product_name:Electra Straight 8 1 (20-inch) - Boy's - 2018, totalquantity:24
# product_name:Electra Straight 8 3i (20-inch) - Boy's - 2017, totalquantity:47
# product_name:Electra Straight 8 3i - 2018, totalquantity:37
# product_name:Electra Super Moto 8i - 2018, totalquantity:35
# product_name:Electra Superbolt 1 20" - 2018, totalquantity:9
# product_name:Electra Superbolt 3i 20" - 2018, totalquantity:43
# product_name:Electra Sweet Ride 1 (20-inch) - Girl's - 2018, totalquantity:41
# product_name:Electra Tiger Shark 1 (20-inch) - Boys' - 2018, totalquantity:44
# product_name:Electra Tiger Shark 3i (20-inch) - Boys' - 2018, totalquantity:23
# product_name:Electra Tiger Shark 3i - 2018, totalquantity:41
# product_name:Electra Townie 7D (20-inch) - Boys' - 2017, totalquantity:38
# product_name:Electra Townie Commute Go! - 2018, totalquantity:40
# product_name:Electra Townie Original 1 - 2018, totalquantity:12
# product_name:Electra Townie Original 1 Ladies' - 2018, totalquantity:38
# product_name:Electra Townie Original 21D EQ Ladies' - 2018, totalquantity:36
# product_name:Electra Townie Original 21D Ladies' - 2018, totalquantity:16
# product_name:Electra Townie Original 3i EQ - 2017/2018, totalquantity:31
# product_name:Electra Townie Original 3i EQ Ladies' - 2018, totalquantity:17
# product_name:Electra Townie Original 7D - 2015/2016, totalquantity:43
# product_name:Electra Townie Original 7D EQ - 2018, totalquantity:34
# product_name:Electra Treasure 1 20" - 2018, totalquantity:48
# product_name:Electra Treasure 3i 20" - 2018, totalquantity:29
# product_name:Electra White Water 3i - 2018, totalquantity:43
# product_name:Haro Downtown 16 - 2017, totalquantity:44
# product_name:Haro Flightline One ST - 2017, totalquantity:47
# product_name:Haro Shift R3 - 2017, totalquantity:41
# product_name:Haro Shredder Pro 20 - 2017, totalquantity:23
# product_name:Haro SR 1.2 - 2017, totalquantity:29
# product_name:Heller Shagamaw Frame - 2016, totalquantity:26
# product_name:Heller Shagamaw GX1 - 2018, totalquantity:30
# product_name:Pure Cycles Vine 8-Speed - 2016, totalquantity:27
# product_name:Pure Cycles Western 3-Speed - Women's - 2015/2016, totalquantity:34
# product_name:Pure Cycles William 3-Speed - 2016, totalquantity:43
# product_name:Ritchey Timberwolf Frameset - 2016, totalquantity:45
# product_name:Strider Classic 12 Balance Bike - 2018, totalquantity:46
# product_name:Strider Sport 16 - 2018, totalquantity:36
# product_name:Sun Bicycles Biscayne Tandem 7 - 2017, totalquantity:16
# product_name:Sun Bicycles Biscayne Tandem CB - 2017, totalquantity:36
# product_name:Sun Bicycles Brickell Tandem 7 - 2017, totalquantity:30
# product_name:Sun Bicycles Drifter 7 - 2017, totalquantity:19
# product_name:Sun Bicycles Drifter 7 - Women's - 2017, totalquantity:46
# product_name:Sun Bicycles ElectroLite - 2017, totalquantity:27
# product_name:Sun Bicycles Lil Bolt Type-R - 2017, totalquantity:27
# product_name:Sun Bicycles Lil Kitt'n - 2017, totalquantity:48
# product_name:Sun Bicycles Revolutions 24 - 2017, totalquantity:37
# product_name:Sun Bicycles Revolutions 24 - Girl's - 2017, totalquantity:33
# product_name:Sun Bicycles Spider 3i - 2017, totalquantity:46
# product_name:Sun Bicycles Streamway 3 - 2017, totalquantity:24
# product_name:Sun Bicycles Streamway 7 - 2017, totalquantity:11
# product_name:Surly Big Fat Dummy Frameset - 2018, totalquantity:46
# product_name:Surly ECR - 2018, totalquantity:37
# product_name:Surly ECR Frameset - 2018, totalquantity:37
# product_name:Surly Ice Cream Truck Frameset - 2016, totalquantity:38
# product_name:Surly Krampus - 2018, totalquantity:38
# product_name:Surly Krampus Frameset - 2018, totalquantity:26
# product_name:Surly Ogre Frameset - 2017, totalquantity:42
# product_name:Surly Pack Rat - 2018, totalquantity:41
# product_name:Surly Pack Rat Frameset - 2018, totalquantity:28
# product_name:Surly Steamroller - 2017, totalquantity:49
# product_name:Surly Straggler - 2016, totalquantity:49
# product_name:Surly Troll Frameset - 2018, totalquantity:41
# product_name:Surly Wednesday - 2017, totalquantity:22
# product_name:Surly Wednesday Frameset - 2016, totalquantity:34
# product_name:Surly Wednesday Frameset - 2017, totalquantity:32
# product_name:Trek 1120 - 2018, totalquantity:41
# product_name:Trek 820 - 2018, totalquantity:42
# product_name:Trek Boone 5 Disc - 2018, totalquantity:48
# product_name:Trek Boone 7 - 2017, totalquantity:29
# product_name:Trek Boone Race Shop Limited - 2017, totalquantity:17
# product_name:Trek Conduit+ - 2018, totalquantity:22
# product_name:Trek Crockett 5 Disc - 2018, totalquantity:37
# product_name:Trek Crockett 7 Disc - 2018, totalquantity:34
# product_name:Trek CrossRip 1 - 2018, totalquantity:28
# product_name:Trek CrossRip 2 - 2018, totalquantity:29
# product_name:Trek CrossRip+ - 2018, totalquantity:47
# product_name:Trek Domane AL 2 - 2018, totalquantity:36
# product_name:Trek Domane AL 3 Women's - 2018, totalquantity:14
# product_name:Trek Domane ALR 3 - 2018, totalquantity:40
# product_name:Trek Domane ALR 4 Disc - 2018, totalquantity:20
# product_name:Trek Domane ALR 4 Disc Women's - 2018, totalquantity:27
# product_name:Trek Domane ALR 5 Disc - 2018, totalquantity:39
# product_name:Trek Domane ALR 5 Gravel - 2018, totalquantity:24
# product_name:Trek Domane ALR Disc Frameset - 2018, totalquantity:41
# product_name:Trek Domane ALR Frameset - 2018, totalquantity:34
# product_name:Trek Domane S 5 Disc - 2017, totalquantity:39
# product_name:Trek Domane S 6 - 2017, totalquantity:21
# product_name:Trek Domane SL 5 Disc Women's - 2018, totalquantity:34
# product_name:Trek Domane SL 6 - 2017, totalquantity:16
# product_name:Trek Domane SL 6 - 2018, totalquantity:42
# product_name:Trek Domane SL 6 Disc - 2018, totalquantity:25
# product_name:Trek Domane SL 8 Disc - 2018, totalquantity:39
# product_name:Trek Domane SL Disc Frameset - 2017, totalquantity:30
# product_name:Trek Domane SL Frameset - 2018, totalquantity:35
# product_name:Trek Domane SLR 6 - 2018, totalquantity:18
# product_name:Trek Domane SLR 6 Disc - 2018, totalquantity:30
# product_name:Trek Domane SLR 6 Disc Women's - 2018, totalquantity:44
# product_name:Trek Domane SLR 8 Disc - 2018, totalquantity:24
# product_name:Trek Domane SLR Disc Frameset - 2018, totalquantity:35
# product_name:Trek Domane SLR Frameset - 2018, totalquantity:5
# product_name:Trek Emonda S 4 - 2017, totalquantity:27
# product_name:Trek Emonda S 5 - 2017, totalquantity:37
# product_name:Trek Emonda SL 6 Disc - 2018, totalquantity:43
# product_name:Trek Emonda SLR 6 - 2018, totalquantity:31
# product_name:Trek Emonda SLR 8 - 2018, totalquantity:29
# product_name:Trek Farley Alloy Frameset - 2017, totalquantity:27
# product_name:Trek Farley Carbon Frameset - 2018, totalquantity:41
# product_name:Trek Fuel EX 5 27.5 Plus - 2017, totalquantity:25
# product_name:Trek Fuel EX 5 Plus - 2018, totalquantity:39
# product_name:Trek Fuel EX 8 29 - 2016, totalquantity:36
# product_name:Trek Fuel EX 9.8 27.5 Plus - 2017, totalquantity:30
# product_name:Trek Fuel EX 9.8 29 - 2017, totalquantity:41
# product_name:Trek Kickster - 2018, totalquantity:43
# product_name:Trek Kids' Dual Sport - 2018, totalquantity:34
# product_name:Trek Lift+ Lowstep - 2018, totalquantity:39
# product_name:Trek Madone 9 Frameset - 2018, totalquantity:43
# product_name:Trek Madone 9.2 - 2017, totalquantity:43
# product_name:Trek Marlin 6 - 2018, totalquantity:27
# product_name:Trek MT 201 - 2018, totalquantity:43
# product_name:Trek Neko+ - 2018, totalquantity:28
# product_name:Trek Powerfly 5 Women's - 2018, totalquantity:17
# product_name:Trek Powerfly 7 FS - 2018, totalquantity:17
# product_name:Trek Precaliber 12 Girls - 2017, totalquantity:43
# product_name:Trek Precaliber 16 Boy's - 2018, totalquantity:37
# product_name:Trek Precaliber 16 Boys - 2017, totalquantity:39
# product_name:Trek Precaliber 16 Girls - 2017, totalquantity:39
# product_name:Trek Precaliber 20 6-speed Boy's - 2018, totalquantity:27
# product_name:Trek Precaliber 20 Boy's - 2018, totalquantity:41
# product_name:Trek Precaliber 24 (21-Speed) - Girls - 2017, totalquantity:16
# product_name:Trek Precaliber 24 (7-Speed) - Boys - 2018, totalquantity:30
# product_name:Trek Precaliber 24 21-speed Boy's - 2018, totalquantity:43
# product_name:Trek Precaliber 24 21-speed Girl's - 2018, totalquantity:40
# product_name:Trek Procal AL Frameset - 2018, totalquantity:23
# product_name:Trek Procaliber 6 - 2018, totalquantity:24
# product_name:Trek Remedy 29 Carbon Frameset - 2016, totalquantity:13
# product_name:Trek Remedy 9.8 - 2017, totalquantity:35
# product_name:Trek Remedy 9.8 27.5 - 2018, totalquantity:19
# product_name:Trek Session DH 27.5 Carbon Frameset - 2017, totalquantity:32
# product_name:Trek Silque SLR 8 Women's - 2017, totalquantity:12
# product_name:Trek Slash 8 27.5 - 2016, totalquantity:28
# product_name:Trek Super Commuter+ 8S - 2018, totalquantity:25
# product_name:Trek Superfly 20 - 2018, totalquantity:37
# product_name:Trek Superfly 24 - 2017/2018, totalquantity:35
# product_name:Trek Verve+ Lowstep - 2018, totalquantity:40
# product_name:Trek X-Caliber 8 - 2018, totalquantity:46

# %% [markdown]
# ---
#
# ## Level 3: Advanced – Complex Joins and Subqueries
# (using Pandas read_sql)

# %% [markdown]
# ### Task 1: Retrieve the Top 5 Products with the Highest Total Sales Revenue

# %%
query=""" select products.product_name,sum(order_items.list_price*order_items.quantity)as TotalRevenue 
from products
join order_items
on products.product_id=order_items.product_id
group by products.product_name
order by TotalRevenue desc limit 5
"""
rows=pd.read_sql(query,connection)
rows
# Out:
# C:\Users\alaaa\AppData\Local\Temp\ipykernel_3076\1637032239.py:8: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   rows=pd.read_sql(query,connection)
#                     product_name  TotalRevenue
# 0       Trek Slash 8 27.5 - 2016     615998.46
# 1           Trek Conduit+ - 2016     434998.55
# 2       Trek Fuel EX 8 29 - 2016     414698.57
# 3    Surly Straggler 650b - 2016     253829.49
# 4  Trek Domane SLR 6 Disc - 2017     236499.57

# %% [markdown]
# ### Task 2: Find the Customers Who Placed the Most Orders in June, November 2018

# %%
query=""" select customers.customer_id,customers.first_name,customers.last_name,count(orders.order_id) as TotalOrders
from customers join orders
on customers.customer_id=orders.customer_id
where orders.order_date between "2018-6-01" and "2018-6-30"
or orders.order_date between "2018-11-01" and "2018-11-30"
group by customers.customer_id,customers.first_name,customers.last_name
order by TotalOrders desc
"""
rows=pd.read_sql(query,connection)
rows
# Out:
# C:\Users\alaaa\AppData\Local\Temp\ipykernel_3076\2567469148.py:9: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   rows=pd.read_sql(query,connection)
#    customer_id first_name last_name  TotalOrders
# 0          135    Dorthey   Jackson            1
# 1            1      Debra     Burks            1
# 2            7    Latasha      Hays            1

# %% [markdown]
# ### Task 3: List All Stores with Their Total Stock Quantities for All Products

# %%
query=""" select stores.store_name,sum(stocks.quantity) as TotalStock
from stores join stocks
on stores.store_id=stocks.store_id
group by stores.store_name
"""
rows=pd.read_sql(query,connection)
rows
# Out:
# C:\Users\alaaa\AppData\Local\Temp\ipykernel_3076\657380733.py:6: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   rows=pd.read_sql(query,connection)
#          store_name  TotalStock
# 0     Baldwin Bikes      4359.0
# 1     Rowlett Bikes      4620.0
# 2  Santa Cruz Bikes      4532.0

# %% [markdown]
# ### Task 4: Retrieve Staff Members Who Work at Stores Located in a Specific State
# California (CA) , New York (NY) , Texas (TX)

# %%
query=""" select staffs.staff_id,staffs.first_name,staffs.last_name,stores.store_name,stores.state
from staffs join stores
on staffs.store_id=stores.store_id
where stores.state in (select state from stores)
"""
rows=pd.read_sql(query,connection)
rows
# Out:
# C:\Users\alaaa\AppData\Local\Temp\ipykernel_3076\2259143966.py:6: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   rows=pd.read_sql(query,connection)
#    staff_id  first_name last_name        store_name state
# 0         1     Fabiola   Jackson  Santa Cruz Bikes    CA
# 1         2      Mireya  Copeland  Santa Cruz Bikes    CA
# 2         3       Genna   Serrano  Santa Cruz Bikes    CA
# 3         4      Virgie   Wiggins  Santa Cruz Bikes    CA
# 4         5    Jannette     David     Baldwin Bikes    NY
# 5         6   Marcelene     Boyer     Baldwin Bikes    NY
# 6         7      Venita    Daniel     Baldwin Bikes    NY
# 7         8        Kali    Vargas     Rowlett Bikes    TX
# 8         9       Layla   Terrell     Rowlett Bikes    TX
# 9        10  Bernardine   Houston     Rowlett Bikes    TX

# %% [markdown]
# ### Task 5: Identify the Categories of Products with the Highest Total Revenue

# %%
query=""" select categories.category_name,sum(order_items.list_price*order_items.quantity) as TotalRevenue
from categories join products
on categories.category_id=products.category_id
join order_items
on order_items.product_id=products.product_id
group by categories.category_name 
order by TotalRevenue desc limit 1
"""
rows=pd.read_sql(query,connection)
rows
# Out:
# C:\Users\alaaa\AppData\Local\Temp\ipykernel_3076\2208520600.py:9: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   rows=pd.read_sql(query,connection)
#     category_name  TotalRevenue
# 0  Mountain Bikes    3030775.71

# %% [markdown]
# ---
# ## Level 4: Expert – Advanced Analytical Queries
# (using Pandas read_sql)

# %% [markdown]
# ### Task 1: Find the Store with the Highest Total Revenue
# Retrieve the store name and total revenue (sum of list_price * quantity) across all orders.

# %%
query=""" select stores.store_name,sum(order_items.list_price*order_items.quantity)as TotalRevenue
from stores join orders
on stores.store_id=orders.store_id
join order_items 
on order_items.order_id=orders.order_id
group by stores.store_name
order by TotalRevenue desc limit 1
"""
rows=pd.read_sql(query,connection)
rows
# Out:
# C:\Users\alaaa\AppData\Local\Temp\ipykernel_3076\1989031699.py:9: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   rows=pd.read_sql(query,connection)
#       store_name  TotalRevenue
# 0  Baldwin Bikes    5826242.21

# %% [markdown]
# ### Task 2: Find all products that have never been ordered.

# %%
query=""" select product_id,product_name
from products 
where product_id not in(
select products.product_id from products join order_items 
on  products.product_id =order_items.product_id)
"""
rows=pd.read_sql(query,connection)
rows
# Out:
# C:\Users\alaaa\AppData\Local\Temp\ipykernel_3076\2079132186.py:7: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   rows=pd.read_sql(query,connection)
#     product_id                                    product_name
# 0            1                                 Trek 820 - 2016
# 1          121                   Surly Krampus Frameset - 2018
# 2          125                    Trek Kids' Dual Sport - 2018
# 3          154           Trek Domane SLR 6 Disc Women's - 2018
# 4          195            Electra Townie Go! 8i Ladies' - 2018
# 5          267                Trek Precaliber 12 Girl's - 2018
# 6          284    Electra Savannah 1 (20-inch) - Girl's - 2018
# 7          291  Electra Sweet Ride 1 (20-inch) - Girl's - 2018
# 8          316            Trek Checkpoint ALR 4 Women's - 2019
# 9          317                    Trek Checkpoint ALR 5 - 2019
# 10         318            Trek Checkpoint ALR 5 Women's - 2019
# 11         319             Trek Checkpoint SL 5 Women's - 2019
# 12         320                     Trek Checkpoint SL 6 - 2019
# 13         321             Trek Checkpoint ALR Frameset - 2019

# %% [markdown]
# ### Task 3: Identify the Customers Who Placed the Fewest Orders
# Retrieve customer names and their total order counts, ordered in ascending order of order count.

# %%
query=""" select customers.customer_id,customers.first_name,customers.last_name,count(orders.order_id) as TotalOrders
from customers join orders
on customers.customer_id=orders.customer_id
group by customers.customer_id, customers.first_name,customers.last_name
order by TotalOrders,customers.customer_id limit 5
"""
rows=pd.read_sql(query,connection)
rows
# Out:
# C:\Users\alaaa\AppData\Local\Temp\ipykernel_3076\2068985368.py:7: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   rows=pd.read_sql(query,connection)
#    customer_id first_name   last_name  TotalOrders
# 0           95    Letitia      Franco            1
# 1           96   Floretta     Higgins            1
# 2           98     Violet  Valenzuela            1
# 3           99      Carie        Kidd            1
# 4          100     Kellie      Franco            1

# %% [markdown]
# ### Task 4: Analyze Monthly Revenue for the Last Year (Specific to 2017)

# %%
query=""" select distinct MONTH(orders.order_date) as month,sum(order_items.list_price*order_items.quantity) as MonthlyRevenue
from orders join order_items 
on orders.order_id=order_items.order_id 
where YEAR(order_date)=2017 
group by month;
"""
rows=pd.read_sql(query,connection)
rows
# Out:
# C:\Users\alaaa\AppData\Local\Temp\ipykernel_3076\1757344520.py:7: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   rows=pd.read_sql(query,connection)
#     month  MonthlyRevenue
# 0       1       316954.77
# 1       2       348740.47
# 2       3       348177.13
# 3       4       254105.57
# 4       5       297754.66
# 5       6       419892.07
# 6       7       255727.63
# 7       8       322553.32
# 8       9       329388.68
# 9      10       345316.18
# 10     11       315881.67
# 11     12       291022.87

# %% [markdown]
# ### Task 5: Find Products That Are Low in Stock Across All Stores
# Identify products where the total stock quantity (across all stores) is less than 100.

# %%
query=""" select products.product_id,products.product_name,sum(stocks.quantity) as TotalStock
from products join stocks
on products.product_id=stocks.product_id
group by  products.product_id,products.product_name
having TotalStock < 100
"""
rows=pd.read_sql(query,connection)
rows
# Out:
# C:\Users\alaaa\AppData\Local\Temp\ipykernel_3076\3967965820.py:7: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   rows=pd.read_sql(query,connection)
#      product_id                              product_name  TotalStock
# 0             1                           Trek 820 - 2016        55.0
# 1             2        Ritchey Timberwolf Frameset - 2016        45.0
# 2             3           Surly Wednesday Frameset - 2016        34.0
# 3             4                  Trek Fuel EX 8 29 - 2016        36.0
# 4             5              Heller Shagamaw Frame - 2016        26.0
# ..          ...                                       ...         ...
# 308         309         Electra Townie Commute 27D - 2018        46.0
# 309         310  Electra Townie Commute 27D Ladies - 2018        31.0
# 310         311          Electra Townie Commute 8D - 2018        70.0
# 311         312  Electra Townie Commute 8D Ladies' - 2018        43.0
# 312         313  Electra Townie Original 1 Ladies' - 2018        38.0
#
# [313 rows x 3 columns]

# %% [markdown]
# ---
#
# ## Level 5: Additional Advanced SQL
# (using Pandas read_sql)

# %% [markdown]
# ### Task 1: Aggregate Sales by City and State
# Write a query to calculate the total sales, average order value, and maximum order value for customers in each city and state.

# %%
query=""" select customers.city,customers.state,count(customers.customer_id) as customer_count,
sum(order_items.list_price*order_items.quantity) as Total_Sales,avg(order_items.list_price*order_items.quantity) as avg_order_value,
max(order_items.list_price*order_items.quantity) as max_order_value
from customers join orders
on customers.customer_id=orders.customer_id
join order_items
on orders.order_id=order_items.order_id
group by customers.city,customers.state
order by Total_Sales desc
"""
rows=pd.read_sql(query,connection)
rows
# Out:
# C:\Users\alaaa\AppData\Local\Temp\ipykernel_3076\4201366902.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   rows=pd.read_sql(query,connection)
#                     city state  customer_count  Total_Sales  avg_order_value  \
# 0           Mount Vernon    NY              60    117010.21      1950.170167
# 1           Ballston Spa    NY              52    110065.34      2116.641154
# 2             San Angelo    TX              53    109729.26      2070.363396
# 3          Baldwinsville    NY              37    105893.45      2861.985135
# 4           Howard Beach    NY              36    104250.51      2895.847500
# ..                   ...   ...             ...          ...              ...
# 190        Copperas Cove    TX               4      3337.94       834.485000
# 191         Far Rockaway    NY               5      3249.94       649.988000
# 192  Springfield Gardens    NY               3      1889.95       629.983333
# 193             Westbury    NY               2      1437.98       718.990000
# 194            Tonawanda    NY               2      1347.99       673.995000
#
#      max_order_value
# 0            9999.98
# 1           11999.98
# 2           10999.98
# 3           12999.98
# 4           23999.98
# ..               ...
# 190          1319.98
# 191           899.98
# 192           879.98
# 193           898.00
# 194           858.00
#
# [195 rows x 6 columns]

# %% [markdown]
# ### Task 2: Find Top-Selling Products in 2018
# Write a query to identify the products with the highest sales volume in the year 2018.

# %%
query=""" select products.product_id,YEAR(orders.order_date) as order_year, products.product_name,sum(order_items.quantity) as total_unit_sold
from orders join order_items
on order_items.order_id=orders.order_id
join products 
on products.product_id = order_items.product_id
where YEAR(orders.order_date)=2018
group by products.product_id,products.product_name
order by total_unit_sold desc;
"""
rows=pd.read_sql(query,connection)
rows
# Out:
# C:\Users\alaaa\AppData\Local\Temp\ipykernel_3076\1322830761.py:10: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   rows=pd.read_sql(query,connection)
#      product_id  order_year                                   product_name  \
# 0            86        2018                    Trek Girl's Kickster - 2017
# 1            92        2018                        Haro Shredder 20 - 2017
# 2           263        2018         Strider Classic 12 Balance Bike - 2018
# 3           235        2018                  Electra Koa 3i Ladies' - 2018
# 4           252        2018      Electra Townie Commute Go! Ladies' - 2018
# ..          ...         ...                                            ...
# 296          44        2018                             Haro SR 1.1 - 2017
# 297         262        2018                             Trek MT 201 - 2018
# 298         250        2018              Electra Townie Go! 8i - 2017/2018
# 299         287        2018  Electra Straight 8 1 (16-inch) - Boy's - 2018
# 300          10        2018                         Surly Straggler - 2016
#
#      total_unit_sold
# 0               12.0
# 1               11.0
# 2               11.0
# 3               11.0
# 4               11.0
# ..               ...
# 296              1.0
# 297              1.0
# 298              1.0
# 299              1.0
# 300              1.0
#
# [301 rows x 4 columns]

# %% [markdown]
# ### Task 3: Calculate Month-over-Month Sales Growth
# Write a query to calculate the month-over-month sales growth for the past years.

# %%
query=""" select YEAR(orders.order_date) as Year, MONTH(orders.order_date) as month,
sum(order_items.quantity) as unit_sold,sum(order_items.quantity*order_items.list_price) as total_sales
from orders join order_items
on order_items.order_id=orders.order_id
group by Year,month
order by Year, month;
"""
rows=pd.read_sql(query,connection)
rows
# Out:
# C:\Users\alaaa\AppData\Local\Temp\ipykernel_3076\1717230893.py:8: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   rows=pd.read_sql(query,connection)
#     Year  month  unit_sold  total_sales
# 0   2016      1      221.0    241184.15
# 1   2016      2      223.0    175768.10
# 2   2016      3      213.0    202157.14
# 3   2016      4      176.0    187223.55
# 4   2016      5      224.0    228701.13
# 5   2016      6      199.0    231120.29
# 6   2016      7      211.0    222854.21
# 7   2016      8      251.0    253130.83
# 8   2016      9      281.0    303282.61
# 9   2016     10      254.0    235051.79
# 10  2016     11      181.0    205315.47
# 11  2016     12      229.0    223695.20
# 12  2017      1      229.0    316954.77
# 13  2017      2      263.0    348740.47
# 14  2017      3      296.0    348177.13
# 15  2017      4      248.0    254105.57
# 16  2017      5      241.0    297754.66
# 17  2017      6      296.0    419892.07
# 18  2017      7      249.0    255727.63
# 19  2017      8      287.0    322553.32
# 20  2017      9      237.0    329388.68
# 21  2017     10      296.0    345316.18
# 22  2017     11      241.0    315881.67
# 23  2017     12      216.0    291022.87
# 24  2018      1      241.0    426301.72
# 25  2018      2      160.0    223941.44
# 26  2018      3      290.0    406701.20
# 27  2018      4      580.0    909179.47
# 28  2018      6        1.0       209.99
# 29  2018      7       11.0     12949.89
# 30  2018      8        9.0     10256.91
# 31  2018      9        4.0      9949.96
# 32  2018     10        8.0      4219.92
# 33  2018     11        8.0     12278.93
# 34  2018     12        4.0      7999.96
